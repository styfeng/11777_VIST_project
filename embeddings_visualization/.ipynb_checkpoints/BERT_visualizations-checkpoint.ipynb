# %%
# ! pip install transformers
# ! pip install adjustText
# ! pip install sentence-transformers

# %%
# %matplotlib inline
import torch
import numpy as np
from tqdm import tqdm
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
import sys
np.set_printoptions(threshold=sys.maxsize)

# %%
plt.rcParams['figure.figsize'] = [100, 60]

# %%
from adjustText import adjust_text

# %%
from transformers import BertTokenizer, BertModel, BertForMaskedLM

# %%
import logging
logging.basicConfig(level=logging.INFO)
# Load BERT.
model = BertModel.from_pretrained('bert-large-uncased-whole-word-masking')
model.to('cuda')
# Set the model to eval mode.
model.eval()
# This notebook assumes CPU execution. If you want to use GPUs, put the model on cuda and modify subsequent code blocks.
#model.to('cuda')
# Load tokenizer.
tokenizer = BertTokenizer.from_pretrained('bert-large-uncased-whole-word-masking')
# Out:
# Some weights of the model checkpoint at bert-large-uncased-whole-word-masking were not used when initializing BertModel: ['cls.predictions.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.seq_relationship.weight', 'cls.predictions.decoder.weight', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %% [markdown]
# ## BERT's vocabulary embeddings.

# %%
wordembs = model.get_input_embeddings()

# %%
def loadLines(filename):
    print("Loading lines from file", filename)
    f = open(filename,'r')
    lines = np.array([])
    for line in f:
        lines = np.append(lines, line.rstrip())
    print("Done. ", len(lines)," lines loaded!")
    return lines

# %%
bertwords_sents = loadLines('vocab_sents.txt')
bertwords_captions = loadLines('vocab_captions.txt')
bertwords = bertwords_sents
vocab_size = len(bertwords)
# bertwords = loadLines('vocab.txt')
# Out:
# Loading lines from file vocab_sents.txt
# Done.  12650  lines loaded!
# Loading lines from file vocab_captions.txt
# Done.  9661  lines loaded!

# %%
# Convert the vocabulary embeddings to numpy.
# allinds = np.arange(0,model.config.vocab_size,1)
allinds = np.arange(0,vocab_size,1)
inputinds = torch.LongTensor(allinds)
bertwordembs = wordembs(inputinds.to('cuda')).to('cpu').detach().numpy()

# %%
bertwordembs.shape
# Out:
# (12650, 1024)

# %%
# Determine vocabulary to use for t-SNE/visualization. The indices are hard-coded based partially on inspection:
# bert_char_indices_to_use = np.arange(999, 1063, 1)
# bert_voc_indices_to_plot = np.append(bert_char_indices_to_use, np.arange(1996, 5932, 1))
# bert_voc_indices_to_use = np.append(bert_char_indices_to_use, np.arange(1996, 11932, 1))
np.random.seed(123456)
bert_voc_indices_to_plot = np.random.permutation(vocab_size)[:4000]
bert_voc_indices_to_use = np.arange(vocab_size)

# %%
print(len(bert_voc_indices_to_plot))
print(len(bert_voc_indices_to_use))
# Out:
# 4000
# 12650

# %%
print(bertwords[bert_voc_indices_to_use])
# Out:
# ['multiples' 'stripe' 'crucial' 'hauling' 'anchors' 'sunflowers' 'classy'
#  'flies' 'story' '1700' 'lambo' 'expansive' 'maddy' 'boss' 'feldspar'
#  'promoting' 'shhhh' 'foil' 'wood' 'departs' 'chaos' 'incomplete' 'flood'
#  'costume' 'omega' 'tech' 'sergeant' 'twin' 'document' 'brisk' 'warming'
#  'technological' 'arcade' 'leading' 'elementary' 'wrong' 'tulips'
#  'captures' 'ready' 'elder' 'express' 'barkers' 'pope' 'victors' 'piece'
#  'debated' 'slightly' 'kayakers' 'forming' 'soaked' 'flirt' 'receiver'
#  'ship' '80th' 'vista' 'guarding' 'protestors' 'hah' 'aka' 'happily'
#  'doherty' 'must' 'abounded' 'sprawling' 'pointy' 'passageway' 'berry'
#  'stink' 'direct' 'reminder' 'rustic' 'children' 'battery' 'masts'
#  'planets' 'hm' 'outlines' 'credentials' 'refreshment' 'fro' 'ceremonial'
#  'corroborate' 'spirit' 'gossip' 'results' 'full' 'acknowledgment'
#  'gourds' 'dome' '24' 'plentiful' 'pagoda' 'abstract' 'bustling'
#  'demonstrations' 'pleased' 'sidelines' 'sampled' 'battered' 'pepper'
#  'disrepair' 'forts' 'intellectual' 'devils' 'radioactive' 'begun'
#  'experiments' 'waits' 'wheelers' 'grilling' 'floated' 'sorry' 'send'
#  'dept' 'engulfed' 'wen' 'wizards' 'spaceships' 'field' 'beagle' 'hook'
#  'mj' 'carousel' 'meters' 'shot' 'apprehend' 'hermit' 'carts' 'flops'
#  'ruin' 'exterior' '24th' 'fido' 'andrews' 'zoologist' 'important' 'swung'
#  'greetings' 'issues' 'mid' 'distinct' 'gardening' 'ryan' 'adventurers'
#  'capped' 'equal' 'intensify' 'sourced' 'check' 'explosive' 'bandana'
#  'cathedral' 'homecoming' 'skateboards' 'sedans' 'calypso' 'pebbled'
#  'shoddy' 'tied' 'receives' 'brides' 'visited' 'perhaps' 'marchers' 'ness'
#  'length' 'lawnmower' 'landed' 'hydrate' 'process' 'feeder' 'tide'
#  'ballpark' 'ancient' 'inland' 'pianist' 'regret' 'personality' '60s'
#  'tightest' 'colette' 'scholarship' 'bloom' 'better' 'pendulum' 'donuts'
#  'boyfriend' 'chats' 'mick' 'mate' 'belts' 'rainy' 'unpacked'
#  'engineering' 'worry' 'cuts' 'greens' 'comfortable' 'hid' 'funnest'
#  'hieroglyphics' 'brung' 'beginning' 'chocolates' 'hugged' 'mountainside'
#  'hiring' 'boulders' 'aspect' 'town' 'emptied' 'stroke' 'trail'
#  'businessman' 'chasing' 'overlapping' 'tears' 'needles' 'navigating'
#  'tarts' 'ang' 'bridge' 'preached' 'rivers' 'strikers' 'persian' 'pausing'
#  'ran' 'shelter' 'volunteers' 'spotted' 'humans' 'unmistakable'
#  'marvelous' 'barbecuing' 'needed' 'parking' 'shopped' 'rumble' 'hoot'
#  'jersey' 'baited' 'dear' 'french' 'salon' 'flawlessly' 'drowning'
#  'propose' 'attractively' 'test' 'hustle' 'cosplayers' 'shacks'
#  'mountainsides' 'fences' 'tent' 'lager' 'acrobats' 'add' 'hospital'
#  'raincoat' 'deeds' 'platters' 'passages' 'togo' 'fine' 'riled' 'felt'
#  'estuary' 'partaking' 'jewel' 'acts' 'envisioned' '1500' 'wrangle'
#  'towards' 'prepping' 'hybrid' 'enlightenment' 'mountaintop' 'never'
#  'temple' 'upturned' 'slamming' 'seeking' 'limbo' 'nasty' 'pinned'
#  'earrings' 'benefited' 'starved' 'cake' 'instance' 'plunder' 'causes'
#  'ditches' 'honeymooned' 'arrivals' 'sorts' 'documenting' 'spanish' 'ive'
#  'abscond' 'therefore' 'captain' 'subject' 'respect' 'worlds' 'collapses'
#  'drifted' 'carrot' 'hostel' 'nursery' 'locked' 'surfer' 'immeasurable'
#  'quirky' 'club' 'breath' 'tomb' 'tradition' 'thanks' 'waist' 'enviously'
#  'cycle' 'punk' 'gloomy' 'airsoft' 'tumble' 'household' 'pomp' 'ahead'
#  'hypnotizing' 'lectured' 'mt' 'roadster' 'selleck' 'president' 'hide'
#  'couch' 'crumbling' 'puffed' 'filed' 'liqueur' 'handbag' 'namely'
#  'seabirds' 'dwindling' 'fizzy' 'moorings' 'irritated' 'opponent' 'paired'
#  'scales' 'swapped' 'intimacy' 'maddie' 'incident' 'portable' 'stay'
#  'triana' 'walrus' 'officially' 'bedroom' 'draft' 'companions' 'cheetos'
#  'sketch' 'package' 'oysters' 'enticingly' 'creation' 'knees' 'mastro'
#  'pleasantly' 'valet' 'guests' 'skyscape' 'baptized' 'lips' 'generated'
#  'dc' 'kangaroo' 'seemed' 'stevens' 'hovel' 'knick' 'division' 'firm'
#  'run' 'kaila' '85th' 'nice' 'taxi' 'flourishing' 'pause' 'unbeknownst'
#  'crafting' 'remember' 'severe' 'featuring' 'dunes' 'forward' 'vibe'
#  'anemones' 'fraternity' 'copies' 'finding' 'ordering' 'upon' 'misbehave'
#  'buster' 'things' 'loom' 'casual' 'gears' 'listener' 'bites'
#  'multicolored' 'keen' 'bob' 'garlic' 'winners' 'specialized' 'trash'
#  'easy' 'restless' 'eagle' 'peril' 'someday' 'choppy' 'decorates' 'beers'
#  'elbow' 'rascals' 'birthing' 'enjoy' 'occurring' 'buddies' 'enlist'
#  'kwon' 'mansion' 'shell' 'otters' 'statues' 'gunny' 'tricycle' 'initial'
#  'radiance' 'pull' 'casting' 'pump' 'recreated' 'choking' 'gunfire'
#  'scare' 'loner' 'circumstance' 'tone' 'artifact' 'faire' 'believin'
#  'bone' 'snag' 'raptor' 'bounds' 'developer' 'sir' 'rewarding'
#  'impeccably' 'lives' 'get' 'seen' 'nectar' 'kite' 'gym' 'chant' 'fix'
#  'lasers' '6pm' 'rocks' 'politics' 'posture' 'insanity' 'lions'
#  'appreciation' 'crutches' 'candle' 'shawl' 'memorable' 'comforts'
#  'sunglasses' 'perceptive' 'solo' 'intention' 'tryout' 'trailed'
#  'recreates' 'tired' 'yellow' 'monk' 'alley' 'reveals' 'identify' 'blog'
#  'cutting' 'arranged' 'weirdness' 'birdseye' 'rent' 'spreading' 'cacti'
#  'clues' 'area' 'bowls' 'astonishing' 'toaster' 'plantations' 'disbelief'
#  'suggestive' 'raiser' 'assured' 'unborn' 'constituents' 'century'
#  'midwives' 'grayish' 'flows' 'glenlivet' 'giddy' '85' 'donations' 'lace'
#  'lock' 'mark' 'wasted' '34' 'ancients' 'sorta' 'applicants' 'skillet'
#  'seattle' 'increase' 'sprawled' 'slog' 'meditating' 'meandering' 'lived'
#  'generation' 'sports' 'wonderful' 'wander' 'lured' 'beep' 'cutouts'
#  'macro' 'cyclocross' 'saluted' 'cultures' 'behavior' 'horn' 'ugliest'
#  'dangerously' 'system' 'pigment' 'skyline' 'knocked' 'romances'
#  'quantities' 'f' 'remark' 'fountain' 'x' 'fourth' 'neat' 'case' 'tigers'
#  'gamely' 'brutal' 'icy' 'cho' 'singh' 'towing' 'fellow' 'destinations'
#  'restaurant' 'flocks' 'brush' 'clearer' 'knee' 'minutes' 'shining'
#  'debating' 'remind' 'meanders' 'sundae' 'gnome' 'airline' 'pavilion'
#  'definite' 'sent' 'makeover' 'uneasiness' 'unfortunate' 'suit' 'webbing'
#  'crawl' 'cheers' 'dye' 'victorian' 'ten' 'recognize' 'shrubby' 'honors'
#  'dreamer' 'stank' 'boughs' 'alluring' 'confessed' 'using' 'studios'
#  'consistent' 'gull' 'session' 'despair' 'strange' 'contrasting'
#  'ambassador' 'contents' 'nosebleeds' '37' 'complain' 'days' 'raoul'
#  'wrinkly' 'maintain' 'breathtaking' 'peaks' 'highlight' 'tropics'
#  'telescope' 'amigos' 'planned' 'creepy' 'exchanged' 'jagged' 'ex'
#  'wisdom' 'bubbling' 'alfie' 'vest' 'feast' 'cash' 'stress' 'ok' 'teenage'
#  'coats' 'handpicked' 'exposition' 'kep' 'structurally' 'djing' 'choose'
#  'kings' 'dressed' 'whitewall' 'academic' 'assumed' 'owns' 'smothering'
#  'indicating' 'scifi' 'managed' 'suprised' 'realize' 'suck' 'aline' 'uh'
#  'doubting' 'dinghy' 'allowing' 'flexibility' 'muscle' 'fiancee' 'stacked'
#  'executed' 'considered' 'shes' 'tally' 'medals' 'cops' 'docs' 'sally'
#  'breaks' 'grilled' 'sketchy' 'section' 'disturb' 'browns' 'proving'
#  'unstoppable' 'suitcase' 'caller' 'deliver' 'martins' 'benji' 'satanic'
#  'cool' 'puke' 'joining' 'smitten' 'outdo' 'professionally' 'properties'
#  'oddball' 'observe' 'simplicity' 'topiary' 'born' 'prestigious' 'anxious'
#  'filing' 'increases' 'labeling' 'weekend' 'luxurious' 'departed'
#  'forests' 'unhampered' 'giraffes' 'history' 'action' 'trespassing'
#  'repainted' 'weave' 'brews' 'nauseated' 'string' 'lays' 'guest'
#  'paintings' 'warning' 'taxis' 'combination' 'studio' 'drugged' 'appear'
#  'gusto' 'proceed' 'crawls' 'stitch' 'flowed' '1940' 'steam' 'keyboards'
#  'casualty' 'mountains' 'leeroy' 'trevi' 'stream' 'raising' 'autographs'
#  'sake' 'detergent' 'foreign' 'bulls' 'bragging' 'always' 'sell' 'gosh'
#  'pipe' 'waterfront' 'hallways' 'corks' 'soto' 'decorative' 'seared'
#  'extended' 'hut' 'dream' 'potatoes' 'boogie' 'eccentric' 'teammate'
#  'eternity' 'fires' 'cracking' 'extra' 'ride' 'filled' 'flung' 'curvy'
#  'dues' 'promises' 'taj' 'reddick' 'skull' 'bowling' 'winding'
#  'passionately' 'working' 'soaking' 'slices' 'cobblers' 'upkeep' 'tress'
#  'hershey' 'creeps' 'salvage' 'messes' 'online' 'farmer' 'musketeer'
#  'distributing' 'questions' 'staffers' 'spongebob' 'freaky' 'parrot'
#  'universal' 'brain' 'jr' 'consume' 'tribal' 'yachts' 'speech' 'exercise'
#  'mock' 'opposite' 'cement' 'cozying' 'trademark' 'meats' 'zoomed'
#  'downright' 'julie' 'layup' 'reuse' 'swirling' 'udon' 'skateboarder'
#  'renowned' 'headed' 'visibility' 'whale' 'mustaches' 'cornflake' 'stick'
#  'snacking' 'sides' 'demanded' 'defected' 'hurricanes' 'cray' 'oblivious'
#  'promote' 'bleak' 'solitude' 'flavored' 'shelters' 'moisture' 'pumpkins'
#  'gladly' 'embark' 'proud' 'thunderstorm' 'beaches' 'sri' 'free'
#  'strangest' 'mantis' 'sporting' 'rooftops' 'bock' 'kit' 'listed' 'step'
#  'receivers' 'terminal' 'sexist' 'wonder' 'figure' 'command' 'horror'
#  'afternoons' 'flooding' 'going' 'concrete' 'daredevil' 'martial'
#  'branches' 'broadway' 'instruments' 'fertilize' 'shriek' 'menus'
#  'grueling' 'dudas' 'sneak' 'afterall' 'aligning' 'joanie' 'rally' 'hips'
#  'bast' 'imac' 'boob' 'nursing' 'communal' 'season' 'roses' 'audio'
#  'menora' 'approved' 'bay' 'jane' 'mayfly' 'cook' 'lagoon' 'cup' 'serine'
#  'stating' 'passing' 'barges' 'successes' 'reposition' 'bullet' 'kudzu'
#  'obscure' 'music' 'neglected' 'army' 'raindrops' 'boat' 'alright'
#  'succesful' 'height' 'ranger' 'realistic' 'locker' 'years' 'wrestle'
#  'names' 'told' 'fashions' 'funerals' 'marginal' 'log' 'fastening'
#  'cuddles' 'chaotic' 'initially' 'records' 'frightened' 'sells' 'authors'
#  'kickball' 'gallery' 'owl' 'assembled' 'simulates' 'whisper' 'sops'
#  'outdid' 'gliding' 'organizer' 'twisted' 'exactly' 'goonies' 'vice'
#  'guiding' 'toast' 'gathered' 'lead' 'excellent' 'toad' 'amusement'
#  'exciting' 'clubbing' 'migrants' 'hrs' 'design' 'riot' 'tailbone'
#  'scripts' 'attempting' 'devastating' 'motorcycle' 'permanent' 'sippy'
#  'climate' 'indian' 'sundries' 'dino' 'victorious' 'cranny' 'doggie'
#  'cavorted' 'enhanced' 'ease' 'relaxed' 'prairie' 'able' 'warthog'
#  'chocolatey' 'headband' 'would' 'meetings' 'surrounded' 'chirps'
#  'technology' 'overhanging' 'resembled' 'ferns' 'parents' 'harms' 'mitten'
#  'badge' 'conquistador' 'stylish' 'tie' 'belief' 'viper' 'mickey' 'cooler'
#  'whizzed' 'korean' 'sedimentary' 'telecast' 'confidence' 'fully'
#  'portrayed' 'charlize' 'smoothies' 'innuendo' 'sync' 'fateful' 'lady'
#  'ranges' 'caliber' 'layer' 'skivvies' 'hawks' 'breaststroke' 'glassy'
#  'recipients' 'displays' 'ambulance' 'magnifying' 'freaking' 'delivering'
#  'topping' 'viewpoint' 'pack' 'youngsters' 'spotter' 'often' 'rehearsals'
#  'interlude' 'recall' 'festively' 'framing' 'ports' 'boxer' 'savan'
#  'wieners' 'downstairs' 'whistles' 'cruises' 'seaman' 'sun' 'doors'
#  'hapless' 'uncanny' 'altar' 'symbolic' 'goose' 'trip' 'writing' 'wire'
#  'dawn' 'tiptoes' 'teenagers' 'diners' 'wishes' 'petals' 'critters'
#  'onlookers' 'prostitutes' 'opponents' 'firing' 'international'
#  'airbrushed' 'awakes' 'ping' 'gadgets' 'dashes' 'crackled' 'tomorrow'
#  'billion' 'numerous' 'mobile' 'righted' 'wither' 'solemnly' 'gun'
#  'commanding' 'turbo' '106' 'bedrooms' 'silence' 'celebrations'
#  'entertains' 'urged' 'supporters' 'peppered' 'glasses' 'pours' 'vey'
#  'mushrooms' 'modest' 'expertise' 'coves' 'pools' 'sing' 'tearing'
#  'cookouts' 'thundering' 'farthest' 'joint' 'lounging' 'ticked' 'laundry'
#  'geared' 'dined' 'regularly' 'pasture' 'future' 'skinny' '2009' 'advance'
#  'editor' 'making' 'lil' 'congrats' 'ate' 'nails' 'physics' 'arts' 'earth'
#  'kool' 'boggling' 'hastily' 'shorts' 'chews' 'obsession' 'equipped'
#  'squirting' 'much' 'player' 'argentine' 'creativity' 'cooling' 'rack'
#  'advances' 'mario' 'lightbulb' 'trekking' 'choreographed' 'coyotes'
#  'teeth' 'cherished' 'preformed' 'grandpas' 'boxes' 'instructions'
#  'admired' 'balloon' 'flirty' 'sensation' 'anoint' 'cigarette' 'expert'
#  'outskirts' 'spare' 'conscious' 'sampling' 'hitch' 'informative'
#  'renovate' 'excavation' 'worship' 'parliament' 'benefactors' 'creeping'
#  'honk' 'calmly' 'bulbs' 'concessions' 'eerie' 'sleigh' 'neck' 'kidding'
#  'jerry' 'shabby' 'bacon' 'flour' 'marshland' 'desert' 'impossible'
#  'coaching' 'swooped' 'stricter' 'mostly' 'garage' 'actions' 'decaying'
#  'sleeper' 'items' 'entering' 'cheeseburgers' 'reflecting' 'cameraman'
#  'jetty' 'invaded' 'latest' 'hamster' 'blocking' 'casinos' 'brief'
#  'certificate' 'expectantly' 'grave' 'ginormous' 'poems' 'talked'
#  'rigorous' 'reef' 'whoops' 'wonders' 'cooperated' 'intently' 'novelties'
#  'professionalism' 'garnish' 'platform' 'churned' 'sipping' 'sailboats'
#  'bailed' 'slinger' 'pairings' 'tractor' 'medium' 'sung' 'holes' 'pilings'
#  'prizes' 'pedaled' 'gravel' 'seminars' 'grove' 'consuming' 'duets'
#  'cucumber' 'manner' 'coy' 'opened' 'stategy' 'discomfort' 'maniacally'
#  'expectations' 'duel' 'except' 'suspect' 'sense' 'winery' 'onion' 'trick'
#  'fare' 'comforted' 'dense' 'nagging' 'tea' 'aquarium' 'cove' 'circles'
#  'piano' 'lawyer' 'stiff' 'hardy' 'steal' 'cracks' 'pier' 'crustaceans'
#  'bands' 'reassured' 'erratic' 'jed' 'trumpet' 'popped' 'toes'
#  'breathable' 'reviews' 'worthy' 'bonded' '66' 'universe' 'suggest'
#  'springs' 'overcast' 'dives' 'airplanes' 'st' 'enrolled' 'capsule' 'rice'
#  'say' 'prisons' 'routines' 'calendar' 'meter' 'disagree' 'freaked'
#  'brisket' 'mended' 'phew' 'dyed' 'austerity' 'gymnastic' 'rails'
#  'counting' 'grace' 'scooby' 'chacha' 'newer' 'victim' 'prehistoric'
#  'satan' 'marijuana' 'banquet' 'gramma' 'tiger' 'called' 'idiots' 'runner'
#  'fosters' 'peloton' 'machu' '100000' 'transportation' 'joyously'
#  'tackiest' 'erupts' 'doctors' 'previous' 'persevere' 'musk' 'childrens'
#  'campsite' 'lifeless' 'fear' 'dint' 'retired' '4pm' 'slam' 'pays' 'half'
#  'sledding' 'plea' 'eel' 'ambiance' 'goodbyes' 'comfortably' 'bounty'
#  'carnage' 'homeless' 'introductory' 'fancier' 'motorcyclists' 'miso'
#  'pads' 'vacationer' 'impatient' 'buck' 'keg' 'outlining' 'ms' 'jessica'
#  'bemused' 'shore' '12' 'kissing' 'applies' 'choir' 'honorees' 'breathers'
#  'evolved' 'kinda' 'hopeful' 'illuminates' 'teens' 'member' '20th'
#  'cadillac' 'giggles' 'warm' 'hurdles' 'invigorating' 'signaled' 'unsafe'
#  'meetup' 'got' 'covered' 'elderly' 'wheel' 'ultra' 'flyers' 'director'
#  'smoke' 'distraction' 'anal' 'menorah' 'pioneer' 'clear' 'vaulted'
#  'recovery' 'illusions' 'rex' '100' 'brr' 'primarily' 'oilfields' 'yum'
#  'childhood' 'dissent' 'floating' 'vending' 'gem' 'airplane' 'sacred'
#  'scantily' 'palaces' 'bargain' 'partiers' 'glade' 'jets' 'dates'
#  'sparred' 'familiar' 'guitar' 'expressed' 'heck' 'enabled' 'society'
#  'weigh' 'internet' 'fondest' 'suvs' 'simplify' 'stool' 'nuclear' 'cob'
#  'gamblers' 'guys' 'moon' 'perked' 'wiz' 'distinctive' 'velvet' 'addition'
#  'patch' 'exemplified' 'cream' 'cavern' 'gross' 'tracks' 'theaters'
#  'sickness' 'raffle' 'gulf' 'gutter' 'motivated' 'fly' 'riverfront'
#  'risky' 'harbour' 'obstacle' 'graduation' 'scratch' 'depictions' 'walls'
#  'agitated' 'survivors' 'hmmm' 'pregame' 'attracting' 'playoffs' 'pairs'
#  'cleanup' 'pro' 'solution' 'unusable' 'grandpa' 'stormy' 'honeycomb'
#  'members' 'avocado' 'boredom' 'gloomier' 'conveniently' 'tibetan'
#  'smokey' 'faster' 'seethe' 'tough' 'meant' 'grew' 'slaving' 'rebounds'
#  'befriended' 'sputtered' 'engineer' 'helps' 'dough' 'reigning' 'daugher'
#  'belt' 'forget' 'genuine' 'squeezed' 'haunt' 'swift' 'rowboat'
#  'reopening' 'sweetness' 'storms' 'malta' 'straws' 'adventurous' 'systems'
#  'flipping' 'wicker' 'portal' 'padlock' 'supposed' 'pleasing' 'buttons'
#  'smoker' 'bombs' 'traffic' 'darkened' 'demonstrates' 'loyal' 'counter'
#  'pelican' 'patterns' 'wondering' 'cactus' 'crappy' 'avid' 'basics'
#  'style' 'camped' 'iconic' 'bruises' 'exploring' 'concluding' 'attendance'
#  'wealthy' 'doughnut' 'unprecedented' 'salesman' 'vigilant' 'wig'
#  'adjusted' 'bro' 'demand' 'valentine' 'rained' 'bloodbath' 'passion'
#  'grafitti' 'bumpy' 'ravenous' 'yoshiko' 'jeep' 'inflatable' 'markers'
#  'practice' 'coals' 'ducks' 'someones' 'scramble' 'striping' 'sentimental'
#  'hardee' 'spill' 'exhibitions' 'warn' 'ceremonies' 'visual' 'fauna'
#  'sips' 'amed' 'natural' 'myths' 'sought' 'congratulations' 'enticed'
#  'directions' 'accomplishment' 'earned' 'bowler' 'thereby' 'recliner'
#  'mount' 'hearty' 'spots' 'menu' 'constantine' 'epitome' 'extinguished'
#  'form' 'growling' 'heel' 'gave' 'buddha' 'elated' 'paulo' 'grains'
#  'traps' 'hobbled' 'handstand' 'especially' 'fantastic' 'sombrero'
#  'sharing' 'stern' 'watery' 'pondering' 'drags' 'photographers'
#  'waterfalls' 'refueled' 'killer' 'dominated' 'leaves' 'relived' 'effects'
#  'bird' 'mummified' 'sigh' 'intended' 'repaint' 'loudspeaker' 'liquor'
#  'hoping' 'certified' 'buzzed' 'nailed' 'including' 'scholarships' 'aah'
#  'welcoming' 'advertise' 'spoils' 'monitor' 'clip' 'sisters' 'motivate'
#  'mailboxes' 'rolling' 'sad' 'bumper' 'disease' 'wax' 'hydrated'
#  'doorways' 'blends' 'reasons' 'prices' 'observation' 'setting'
#  'encouraging' 'functional' 'gamble' 'mingle' 'hr' 'sightings' 'proudly'
#  'gambling' 'nyc' 'boe' 'shouts' 'licking' 'smoothly' 'visuals' 'sundays'
#  'represents' 'adage' 'condo' 'size' 'living' 'department' 'pendant'
#  'greeting' 'letter' 'afterward' 'suns' 'crowning' 'diamond' 'calls'
#  'program' 'aztec' 'finished' 'meditates' 'space' 'darkens' 'royal'
#  'innocent' 'stoked' 'employed' 'conquer' 'musuem' 'headquarters' 'piers'
#  'bills' 'reporter' 'outing' '1000' 'brotherly' 'masterpiece' 'small'
#  'chilling' 'comics' 'matches' 'interracial' 'countdown' 'deemed' 'cork'
#  'horrific' 'paddling' 'statures' 'outstretched' 'altitude' 'wonderfully'
#  'wet' 'responsibility' 'lexi' 'waterways' 'class' 'hint' 'thanked'
#  'decision' 'melted' 'tends' 'owners' 'pinwheels' 'infrastructure'
#  'grasslands' 'premiere' 'tiaras' 'attendee' 'brothers' 'workers'
#  'contractions' 'omen' 'steady' 'taller' 'dimmed' 'batter' 'improvised'
#  'rush' 'sways' 'heathen' 'shimmered' 'manages' 'banging' 'courthouse'
#  'marble' 'dress' 'grandson' 'mischievously' 'starfish' 'cult' 'newbies'
#  'wired' 'buffs' 'spin' 'microbrews' 'classroom' 'wacky' 'passers'
#  'eleven' 'gardeners' 'electronic' 'uses' 'updating' 'harder' 'wowed'
#  'munch' 'insists' 'obstacles' 'desperate' 'gummy' 'compliment' 'corn'
#  'hiding' 'caucasian' 'grandmothers' 'text' 'monument' 'mill' 'likely'
#  'banister' 'impressive' 'comparison' 'lemons' 'historically' 'starbuck'
#  'ruined' 'smalltown' 'unchanging' 'bearable' 'humming' 'fairgrounds'
#  'curve' 'desire' 'guides' 'pillared' 'obviously' 'caves' 'veered' 'lava'
#  'exiting' 'competes' 'feels' 'adventurer' 'made' 'view' 'walk' 'dinosaur'
#  'shred' 'wooded' 'piggyback' 'skirt' 'barriers' 'melt' 'companies'
#  'coloring' 'billy' 'rainforest' 'skatepark' 'feeds' 'illegal' '13'
#  'prefect' 'creators' 'bunch' 'stinky' 'hungry' 'criss' 'matters'
#  'usually' 'scream' 'zag' 'dormitories' 'geting' 'beard' 'overtime'
#  'experience' 'decorations' 'jen' 'dominant' 'arial' 'truth' 'tangled'
#  'spike' 'accept' 'lush' 'boost' 'large' 'complaints' 'stack' 'gang'
#  'entrees' 'jazzy' 'rocket' 'tranquil' 'floors' 'note' 'woman' 'kariya'
#  'goldenrod' 'seasickness' 'civilians' 'washington' 'owe' 'intrigued'
#  'urchin' 'puking' 'awesome' 'jimmy' 'horseriding' 'quack' 'jungles'
#  'adorable' 'commercial' 'infiltration' 'obvious' 'cavernous' 'remembered'
#  'knock' 'kitchen' 'meyers' 'driveway' 'appetizers' 'helm' 'distractions'
#  'cop' 'golf' 'chemicals' 'vocalist' 'toddler' 'controlling' 'snowmen'
#  'victor' 'catering' 'deliciousness' 'enormity' 'griffins' 'announce'
#  'expect' 'oriented' '56th' 'nonprofit' 'cherubs' 'lay' 'remotes' 'coke'
#  'mean' 'drawing' 'tulip' 'safer' 'paid' 'clownfish' 'dripped' 'tucked'
#  'sprinkler' 'candlesticks' 'moshing' 'dilapidated' 'frivolous' 'lite'
#  'lucked' 'coat' 'wow' 'mermaids' 'venturing' 'speeches' 'together'
#  'crusing' 'goldy' 'wiring' 'dispenser' 'togther' 'quail' 'disgusted'
#  'punching' 'intricately' 'containers' 'affiliate' 'bandmates' 'kung'
#  'jenner' 'charm' 'episode' 'mistakes' 'spicy' 'roundabout' 'laptops'
#  'mans' 'dropped' 'listened' 'reason' 'getaway' 'boaters' 'presenters'
#  'loudest' 'bucked' 'turtle' 'scout' 'cultural' 'springtime' 'dispersed'
#  'oddest' 'drama' 'crate' 'techniques' 'pioneers' 'pine' 'bonfire'
#  'excuse' 'spend' 'decent' 'dons' 'single' 'luckier' 'beyond' 'mater'
#  'upwards' 'assemble' 'announcer' 'bye' 'chemical' 'sven' 'bass'
#  'acknowledges' 'silently' 'breather' 'waving' 'handstands' 'crude'
#  'blaze' 'flaunted' 'raw' 'million' 'browsed' 'pajamas' 'contact'
#  'rotating' 'research' 'wipe' 'protect' 'serenity' 'hiking' 'browsing'
#  'chipper' 'www' 'biked' 'coax' 'outcrop' 'came' 'drumming' 'terrors'
#  'attentively' 'answers' 'cleaned' 'adoptions' 'invading' 'disagrees'
#  'workplace' 'swinging' 'montana' 'hora' 'equally' 'aimed' 'month'
#  'graceful' 'cartwheels' 'invitations' 'procedures' 'vegetables' 'laid'
#  'yoga' 'appearing' 'explored' 'stacks' 'cyclists' 'hungover' 'roadkill'
#  'bows' 'celebration' 'common' 'crispy' 'fellows' 'oncoming' 'effort'
#  'shoved' 'green' 'managing' 'aww' 'billboard' 'yanming' 'deflating'
#  'jeeps' 'glee' 'koala' 'moped' 'ingredients' 'handwritten' 'cocktail'
#  'cry' 'otherworldly' '430' 'coin' 'sundown' 'network' 'jung' 'address'
#  'valentines' 'circled' 'expectation' 'reggae' 'remodeling'
#  'disinterested' 'mccall' 'fictional' 'oblige' 'uncle' 'tug' 'flickered'
#  'crunched' 'lego' 'sniffing' 'barbecue' 'medal' 'ocean' 'adorned'
#  'rematch' 'cowgirls' 'browse' 'raged' 'kill' 'throws' 'sliced' 'wally'
#  'novelty' 'gullible' 'crisp' 'trips' 'tipped' 'pant' 'refrigerator'
#  'deadliest' 'bagpipe' 'fatigued' 'repetitive' 'camper' 'ankles'
#  'beforehand' 'scooters' 'merry' 'quiche' 'curtain' 'cousin' 'incurred'
#  'neighboring' 'exams' 'plummer' 'looked' 'nifty' '70s' 'hamburgers'
#  'griddle' 'nervous' 'winged' 'wtih' 'youth' 'wrenching' 'engagement'
#  'exports' 'foray' 'chopsticks' 'rowing' 'knowledgeable' 'assistance'
#  'custard' 'underneath' 'sole' 'sewage' 'excessive' 'described' 'mandate'
#  'enlivening' 'adorn' 'individual' 'colleges' 'adoring' 'ripped' 'devour'
#  'chess' 'sparkling' 'plan' 'guaranteed' 'waited' 'spooky' 'rendering'
#  'carefully' 'ribbon' 'practices' 'wheels' 'reeled' 'sentence' 'hides'
#  'charms' 'pathway' 'goofed' 'star' 'survive' 'happy' 'tastes' 'lit'
#  'tracker' 'organ' 'ignored' 'shoots' 'phenomenal' 'divers' 'backpacks'
#  'spikes' 'cables' 'insignificant' 'tongue' 'crashed' 'integral' 'courts'
#  'hooray' 'slats' 'arrested' 'clocks' 'stationed' 'stew' 'appeal' '5'
#  'waterpark' 'smokes' 'lu' 'report' 'rumored' 'ingenuity' 'islands'
#  'dreams' 'brings' 'spangled' 'tour' 'unbelievable' 'elevate' 'aardvark'
#  'gift' 'wiggling' 'fedora' 'volunteered' 'seating' 'scrumptious'
#  'fascinated' 'teamwork' 'hire' 'explodes' 'watermelons' 'playdate'
#  'bugles' 'ugly' 'belongings' 'sleds' 'lustily' 'wp' 'chanted' 'holder'
#  'naked' 'knife' '3pm' 'resemblance' 'worker' 'blasting' 'tells' 'drains'
#  'perfectly' 'bridesmaids' 'maintaining' 'loaned' 'colours' 'bought'
#  'example' 'gruesome' 'utility' 'award' 'fanny' 'soliders' 'moustache'
#  'awesomely' 'safety' 'hey' 'bent' 'cowboy' 'mesmerizing' 'grasp'
#  'colored' 'moods' 'day' 'dare' 'worked' 'beverage' 'torch' 'dirty'
#  'beachfront' 'fixed' 'rural' 'matt' 'counted' 'walking' 'newlyweds'
#  'extremes' 'dedication' 'recieved' 'wafted' 'trys' 'riveted' 'playground'
#  'commemorated' 'cotswold' 'presentations' 'idol' 'socks' 'self'
#  'repainting' 'ballerinas' 'reach' 'spell' 'inappropriately' 'fright'
#  'ghostly' 'cage' 'cabana' 'gust' 'somebody' 'powdered' 'roasted' 'willy'
#  'commemorating' 'wrapped' 'oversee' 'manicured' 'street' 'thousands'
#  'omelet' 'maintained' 'corridor' 'snowy' 'rouge' 'handwork'
#  'extraordinary' 'dolphins' 'efficiency' 'low' 'watered' 'suprise'
#  'developed' 'mailman' 'graduating' 'marveled' 'searching' 'saluting'
#  'bridle' 'happenings' 'bubba' 'pilots' 'bars' 'interstate' 'baubles'
#  'workweek' 'candy' 'torkelson' 'recruits' 'evenness' 'acting' 'seagull'
#  'angels' 'negative' 'porcupine' 'knight' 'massive' 'authentic' 'debut'
#  'complementary' 'tandem' 'sleepover' 'lavish' 'noodles' 'workday'
#  'flailing' 'resort' 'notorious' 'rescuers' 'swamp' 'braver' 'pork'
#  'peddled' 'crafted' 'quieted' 'solitary' 'thus' 'dollar' 'tons' 'dragged'
#  'digger' 'regulars' 'informal' 'resurrected' 'drum' 'hissed' 'abut'
#  'forty' 'abundant' 'denies' 'pushing' 'teacup' 'flower' 'booze' 'data'
#  'flowering' 'eve' 'sandal' 'wonka' 'servings' 'crazy' 'memorabilia'
#  'icons' 'governments' 'bid' 'sponsored' 'virgin' 'leaked' 'blimps'
#  'punctual' 'gingerbread' 'salads' 'dinos' 'recess' 'nose' 'ingredient'
#  'overseas' 'coo' 'pelicans' 'fishermen' 'streetcar' 'fluently' 'bananas'
#  'regretting' 'plate' 'scarfs' 'prosperous' 'tries' 'recitation' 'gardens'
#  'supply' 'shoshanna' 'cherish' 'dynamic' 'coldest' '16th' 'charge' 'crib'
#  'band' 'candelabra' 'hangers' 'possibility' 'store' 'pursue' 'ornery'
#  'drinker' 'adventure' 'seller' 'necessary' 'wedded' 'echoed' 'fragrant'
#  'braces' 'smog' 'creek' 'medical' 'saved' 'overlooks' 'morning' 'strung'
#  'anxiously' 'offers' 'cutaway' 'dazzling' 'admire' 'provide' 'coastline'
#  'glare' 'satisfaction' 'homeowner' 'watchdog' 'script' 'flying' 'yen'
#  'rehearsal' 'struggles' 'preference' 'homes' 'priest' 'cartoonist'
#  'lovers' 'galleon' 'rabbit' 'versus' 'streamer' 'buffet' 'blintzes'
#  'hotter' 'icee' 'cages' 'rivals' 'government' 'untimely' 'chords'
#  'change' 'ways' 'snake' 'visiting' 'younger' 'spouting' 'existed'
#  'presence' 'casted' 'piloting' 'accordionist' 'weathered' 'convince'
#  'camaraderie' 'mere' 'contemplative' 'detailed' 'chickens' 'enthusiasts'
#  'miked' 'squad' 'reclusive' 'rico' 'mountain' 'surprising' 'iam'
#  'delilah' 'drudgery' 'loneliness' 'yers' 'united' 'shoulder' 'monies'
#  '381' 'skaters' 'jerseys' 'coffees' 'yelled' 'recreation' 'remains'
#  'apprentices' 'coma' 'embarrassment' 'prowl' 'involves' 'inane' 'mob'
#  'entered' 'cozy' 'avenue' 'socialized' 'grasshopper' 'citizen' 'squirrel'
#  'cafes' 'arent' 'thinking' 'glory' 'written' 'buckle' 'peaking'
#  'contrasted' 'accomplishments' 'mister' 'dangling' 'storefront'
#  'embarked' 'tease' 'bounced' 'chunk' 'pits' 'bot' 'cools' 'attached'
#  'mash' 'crowd' 'boundary' 'compelling' 'enchilada' 'tuna' 'uncles'
#  'strobes' 'friendly' 'garbage' 'bojangles' 'desensitized' 'suspiciously'
#  'rain' 'claustrophobic' 'discovery' 'crossfire' 'hobo' 'butter' 'safely'
#  'basking' 'ram' 'formal' 'beds' 'rebuild' 'collins' 'boar' 'driven'
#  'enthralled' 'craziest' 'tranquility' 'biker' 'skimp' 'soaring' 'lessons'
#  'nagendra' 'pink' 'easter' '102' 'clippings' 'donors' 'suited'
#  'undaunted' 'signing' 'performed' 'compass' 'dock' 'reminding' 'scars'
#  '20' 'spelunking' 'adventuring' 'discount' 'beasts' 'performers' 'flare'
#  'via' 'constellation' 'learns' 'lunging' 'pastries' 'shamed' 'spacing'
#  'bus' '400' 'connection' 'pleasure' 'retro' 'shutdown' '40th'
#  'decolletage' 'heavy' 'grander' 'loses' 'keynote' 'mechanisms' 'muck'
#  'accompanied' 'overview' 'passengers' 'supervising' 'jogging' 'discovers'
#  'stolen' 'whirls' 'arc' 'estimated' 'diesels' 'accidentally' 'grandpappy'
#  'buys' 'travels' 'bugs' 'silverware' 'bagel' 'exchange' 'diligently'
#  'gal' 'diner' 'frightening' '1am' 'eyeballs' 'owned' 'bountiful' 'gray'
#  'amazes' 'highlights' 'chinese' 'yukon' 'forced' 'appreciative' 'digest'
#  'viewed' 'earthquakes' 'kimchi' 'calmed' 'catnip' 'received'
#  'practically' 'asteroids' 'sailers' 'snowboard' 'diesel' 'hop' 'favored'
#  'desolate' 'forgotten' 'missed' 'already' 'immigrant' 'awning'
#  'frolicking' 'floor' 'return' 'flares' 'phenomenon' 'kitten' 'sideways'
#  'explained' 'wages' 'desserts' 'kiddie' 'adult' 'funeral' 'thousand'
#  'plight' 'boarder' 'cold' 'sighs' 'oversized' 'turtles' 'peasants' 'fate'
#  'untied' 'encountered' 'emphasize' 'radiate' 'russia' 'leery' 'collage'
#  'pond' 'mc' 'slipping' '10th' 'blur' 'deviled' 'interns' 'parlor' 'swarm'
#  'flaming' 'buses' 'ren' 'economical' 'supplied' 'metal' 'asking' 'flaky'
#  'tripped' 'nervousness' 'swirled' 'sunniness' 'giggling' 'changed'
#  'doted' 'toppings' 'titanic' 'blasted' 'freeway' 'tops' 'sounds'
#  'factory' 'robots' 'brother' 'minimal' 'superhuman' 'staircase'
#  'caravans' 'extinguishers' 'glided' 'stadium' 'louvre' 'snack' 'desired'
#  'detonation' 'composition' 'orientation' 'industrial' 'theatrically'
#  'fill' 'indeed' 'odds' 'halftime' 'longing' 'twisty' 'moment' 'sprints'
#  'midway' 'blueberries' 'replace' 'relay' 'peered' 'pretentious'
#  'releasing' 'arrival' 'outstanding' 'queasy' 'plows' 'wide' 'flamingo'
#  'stupidly' 'cooked' 'perfume' 'sequoia' 'posts' 'keychain' 'eerily'
#  'recommended' 'clashed' 'newspaper' 'regionally' 'bathed' 'eyepatch'
#  'skipping' 'persuade' 'pesky' 'comment' 'motif' 'fondant' 'western' 'rc'
#  'disobey' 'aglow' 'sweat' 'album' 'pyrotechnic' 'act' 'archaeological'
#  'vineyard' 'cohort' '11th' 'launched' 'gulley' 'fingertips' 'glorious'
#  'fabulous' 'males' 'remembers' 'scriptures' 'bug' 'riding' 'cakes' 'coot'
#  'poochie' 'stilts' 'invested' 'begining' 'cloth' 'sneaky' 'spirits'
#  'mothers' 'amber' 'honesty' 'majestically' 'wanting' 'lonely'
#  'enthusiastically' 'hardwood' 'disabilities' 'midair' 'fakes' 'believe'
#  'sooner' 'related' 'rizzo' 'essence' 'doesnt' 'nappers' 'exist' 'minivan'
#  'earn' 'thrived' 'obliged' 'businesses' 'planet' 'segment' 'cart' '8th'
#  'incan' 'precious' 'mummies' 'ceramic' 'keys' 'mail' 'weirdly' 'shaped'
#  'areas' 'groovy' 'emo' 'continue' 'amount' 'perched' 'ropes' 'relaxing'
#  'gravesite' 'illuminate' 'whistle' 'misery' 'piqued' '1998' 'healthiness'
#  'vanquish' 'sleek' 'helmets' 'screamers' 'clad' 'convection' 'current'
#  'ashes' '25' 'jack' 'sheepishly' 'registered' 'indie' 'owner' 'treats'
#  'lantern' 'instructor' 'project' 'since' 'ebay' 'defeated' 'misspelled'
#  'meat' 'mound' 'commence' 'civilization' 'hops' 'bayonet' 'testing'
#  'tank' 'stellar' 'chocolate' 'beware' 'signpost' 'gaps' 'preacher'
#  'deandre' 'politely' 'fruition' 'grill' 'flourishes' 'precision' 'dave'
#  'spray' 'hispanic' 'condos' 'pony' 'kind' 'wrecked' 'sac' 'quit'
#  'recently' 'acdc' 'recovered' 'restoring' 'planks' 'duke' 'unexpected'
#  'survived' 'prayers' 'tasting' 'warmth' 'swings' 'fishes' 'sup'
#  'thanking' 'numbers' 'respective' 'greeter' 'bike' 'midday' 'bizarre'
#  'boy' 'diploma' 'goof' 'lanterns' 'nostalgic' 'ironman' 'nurse'
#  'meringue' 'apartments' 'dull' 'bat' 'purpose' 'coastal' 'scope'
#  'devastated' 'theses' 'twelve' 'target' 'hour' 'wonderment' 'dishing'
#  'hardest' 'rife' 'microphones' 'fleeting' 'lawyers' 'pouring' 'cottage'
#  'unleashed' 'aunt' 'columns' 'jewels' 'issue' 'mouths' 'suppose' 'noise'
#  'splendid' 'slowed' 'debris' 'preserved' 'hipsters' 'fruit' 'mornings'
#  'views' 'accordingly' 'deployment' 'hours' 'clowns' 'campuses' 'netflix'
#  'detailing' 'experimental' 'pyromaniac' 'puzzled' 'decked' 'amazed'
#  'schoolyard' 'doodling' 'complicated' 'egging' 'lifestyle' 'great'
#  'writers' 'complaining' 'rehearsed' 'skies' 'intoxicated' 'senior'
#  'graduate' 'awakening' 'municipal' 'professional' 'epic' 'nighttime'
#  'loggerhead' 'pastures' 'roads' 'joints' 'rented' 'drove' 'wavers'
#  'discussions' 'footage' 'snowboarding' 'epcot' 'wreckage' 'snowfall'
#  'third' 'documentary' 'tipoff' 'onesie' 'map' 'purple' 'purchased'
#  'venue' 'plastic' 'artistic' 'engine' 'covering' 'showcased' 'ultimately'
#  'sailor' 'ceased' 'killed' 'reported' 'dude' 'gunners' 'outrageous'
#  'climbed' 'rotten' 'purchasing' 'outta' 'poodle' 'hundred' 'rights'
#  'paraded' 'rusted' 'peeks' 'rental' 'pathways' 'tome' 'sniffed' 'lecture'
#  'pots' 'congratulating' 'lagoons' 'supposedly' 'generosity' 'texture'
#  'skateboarders' 'readied' 'woop' 'environment' 'startled' 'glamor'
#  'slide' 'cost' 'climbs' 'dances' 'cemetery' 'fend' 'troop' 'nervously'
#  'bruiser' 'presences' 'ribs' 'breakfast' 'clock' '55th' 'rugs' 'ankle'
#  'fairway' 'whatnot' 'flawless' 'restuarant' 'boot' 'roundhouse' 'candles'
#  'deed' 'unpacking' 'argued' 'chilled' 'construct' 'parting' 'hostess'
#  'slippery' 'protecting' 'hitchhike' 'freshening' 'reconnect' 'recharging'
#  'tooth' 'consistency' 'auditorium' 'keepsake' 'risk' 'furry' 'opted'
#  'sodas' 'massage' 'rounding' 'minerals' 'handing' 'snows' 'eye'
#  'screenplay' 'traversing' 'competition' 'mild' 'collection' 'pros'
#  'bullwinkle' 'sojourn' 'lest' 'cones' 'shotguns' 'nugget' 'thirsty'
#  'pinched' 'pants' 'aerial' 'gallons' 'segments' 'kayaks' 'losses'
#  'intersection' 'blame' 'tuesday' 'transport' 'cut' 'foreigners' 'cuter'
#  'brightest' 'scarecrow' 'kayaking' 'mexican' 'penis' 'frames' 'entry'
#  'grooves' 'dimarco' 'dim' 'throng' 'diapers' 'rewarded' 'spoke' '0'
#  'creations' 'tape' 'bricks' 'earsplitting' 'bath' 'votes' '44'
#  'gratefully' 'stache' 'bison' 'impressed' 'highways' 'supported'
#  'darling' 'miracles' 'vist' '103' 'champions' 'tal' 'ensured' 'vile'
#  'healing' 'mist' 'guinness' 'disastrous' 'summit' 'remainder'
#  'cemeteries' 'flats' 'firework' 'orchid' 'footbridge' 'hieroglyphs'
#  'trimmed' 'vampire' 'taco' 'responsible' 'jame' 'pitcher' 'dame'
#  'replied' 'sayan' 'kneeling' 'lousy' 'spacious' 'females' 'pickle'
#  'flash' 'speaks' 'dealing' 'diagrams' 'somewhat' 'correctly' 'cappella'
#  'nana' 'spiritual' 'messy' 'ensemble' 'rearrange' 'packed' 'highest'
#  'bubble' 'impressions' 'pageant' 'plank' 'affair' 'responded' 'mummy'
#  'curiosity' 'turn' 'wetsuit' '5th' 'pronounce' 'bashful' 'devices'
#  'demands' 'replicas' 'shows' 'shopping' 'freshmen' 'roundtable' 'mph'
#  'frisky' 'wrangling' 'wreath' 'plethora' 'turkish' 'jubilant' 'benedict'
#  'entrance' 'loot' 'pinatas' 'tin' 'gut' 'smoky' 'adrenaline' 'infatuated'
#  'tiny' 'unsurprisingly' 'beginner' 'commonplace' 'envy' 'villager' 'brad'
#  'lurch' 'partake' 'bandmate' 'puts' 'attitude' 'article' 'balls' 'live'
#  'luckily' 'lightyear' 'participated' 'hypnotized' 'megadeth' 'wagging'
#  'bmx' 'banana' 'attendant' 'trunk' 'neckline' 'pan' 'special' 'hurry'
#  'coppers' 'intact' 'species' 'milestones' 'lastly' 'distorted'
#  'underwater' 'kid' 'north' 'keeps' 'mosquitos' 'beside' 'tragic'
#  'collects' 'tricia' 'stairs' 'previously' 'cinderella' 'races' 'locking'
#  'dinosaurs' 'dancer' 'gazebo' 'tess' 'oktoberfest' 'gas' 'dumpster'
#  'bobs' 'roomy' 'visits' 'loaded' 'fibers' 'mira' 'goody' 'zip' 'advanced'
#  'overflowing' 'principal' 'explosion' 'similar' 'donate' 'proposal' 'arm'
#  'graveyard' 'inclusive' 'notra' 'layout' 'darkening' 'bowlers' 'homesick'
#  'takeoff' 'footsteps' 'least' 'positions' 'rundown' 'groomsmen' 'correct'
#  'czech' 'global' 'evenly' 'crayons' 'chandelier' 'personalized' 'hero'
#  'founders' 'perspective' 'instead' 'watches' 'focus' 'flannel' 'alas'
#  'messed' 'rabbits' 'aft' 'bratwursts' 'succeeded' 'recalling' 'eight'
#  'primary' 'revere' 'retreat' 'photographs' 'cluster' 'pole' 'thy'
#  'snooze' 'shone' 'bloggers' 'chatted' 'digging' 'crowned' 'subjects'
#  'builders' 'hanging' 'song' 'professors' 'mice' 'true' 'rule' 'cowboys'
#  'bracelet' 'elevator' 'stove' 'veterans' 'moline' 'encompass' 'boasted'
#  'immensely' 'twenty' 'craig' 'congregate' 'achieve' 'feeling' 'eatery'
#  'alignment' 'dynamics' 'waiter' 'rewards' 'confetti' 'announcements'
#  'settings' 'instructors' 'poop' 'river' 'fork' 'mom' 'tickle' 'gifts'
#  'pissed' 'booed' 'josephs' 'natures' 'aching' 'butterfly' 'receive'
#  'tight' 'service' 'bake' 'vistas' 'condition' 'geometric' 'lapse'
#  'honeys' 'sunflower' 'personal' 'waitress' 'costing' 'camping' 'despite'
#  'murdered' 'persuading' 'unparalleled' 'swampy' 'cap' 'clowned' 'easier'
#  'elements' 'participants' 'abundance' 'outposts' 'awash' 'hospitals'
#  'enriched' 'dried' 'timely' 'exists' 'locals' 'departments' 'soups'
#  'machines' 'unicorn' 'percussion' 'starburst' 'wary' 'trolleys' 'chain'
#  'seconds' 'rolf' 'succeeding' 'mazes' 'tribes' 'mixer' 'tendency'
#  'mailbox' 'founder' 'songwriters' 'horseback' 'watchful' 'parks' 'slot'
#  'artisans' 'cupcake' 'spark' 'surrendering' 'matched' 'sinister'
#  'residents' 'kloster' 'hue' 'champaigne' 'ages' 'remembering' 'rickety'
#  'ballgame' 'order' 'julys' 'applications' 'connections' 'hawaiian'
#  'intermission' 'installing' 'corroborating' 'jumped' 'panda' 'aside'
#  'intruders' 'cloudless' 'prettily' 'coveted' 'snuggled' 'maybelle'
#  'granddaughter' 'installation' 'settling' 'captive' 'survival' 'famous'
#  'fewer' 'reefs' 'courses' 'us' 'adjusts' 'withered' 'ginger' 'rivalry'
#  'longest' 'see' 'unimpressed' 'knocker' 'secretaries' 'ambushed' 'scored'
#  'bride' 'immense' 'closets' 'oooo' 'distrust' 'noy' 'lance' 'firehouse'
#  'embarking' 'freakin' 'signs' 'hella' 'mops' 'maker' 'divided' 'split'
#  'stumbles' 'americans' 'ideas' 'shrubs' 'exploits' 'dancers' 'heather'
#  'wipes' 'authentically' 'soar' 'marriage' 'artful' 'hippie' 'matter'
#  'imagination' 'rainbows' 'erect' 'vows' 'resuming' 'tightly' 'even'
#  'positive' 'galore' 'flourished' 'perplexed' 'traveler' 'beige' 'shut'
#  'cycles' 'playtime' 'humbly' 'steve' 'nations' 'sleepers' 'roar'
#  'admiral' 'joyful' 'bicycling' 'abound' 'tab' 'retorts' 'unusual'
#  'unload' 'ringed' 'coordinated' 'thieves' 'meet' 'finds' 'brushing'
#  'orca' 'enchanted' 'lightning' 'rib' 'lin' 'lighter' 'berries' 'galaxies'
#  'falls' 'loopy' 'threaten' 'provided' 'intense' 'fee' 'mauled' 'golds'
#  'find' 'halls' 'volume' 'core' 'glitz' 'vulgar' 'feathers' 'chapels'
#  'safe' 'definitely' 'coney' 'oops' 'worth' 'swimsuits' 'preserve'
#  'expanse' 'rids' 'ridge' 'fertile' 'disturbed' 'dusk' 'trixie' 'engaged'
#  'mindlessly' 'multiple' 'pinks' 'stylist' 'touring' 'foot' 'chillin'
#  'judged' 'scanned' 'ferociously' 'thier' 'blueberry' 'chan' 'jewish'
#  'inspiring' 'patriot' 'illegally' 'tartan' 'around' 'daily' 'fuel'
#  'shrek' 'airshow' 'parachuting' 'fading' 'gay' 'bikers' 'blows'
#  'classics' 'church' 'truly' 'chilli' 'daunting' 'birds' 'juicy' 'clapped'
#  'adore' 'bonus' 'refinements' 'squid' 'medic' 'reduced' 'cycling'
#  'dreamland' 'media' 'offered' 'tundra' 'womans' 'dashboard' 'began'
#  'truck' 'thanksgiving' 'joke' 'academy' 'metals' 'thrill' 'pledging'
#  'louder' 'scampered' 'pregnancy' 'ablaze' 'outages' 'tapping' 'scottish'
#  'lifelike' 'storm' 'motley' 'savored' 'wiped' 'truffles' 'resentment'
#  'metro' 'mayors' 'hung' 'underside' 'rises' 'bean' 'peel' 'nut' 'shinobi'
#  'walker' 'chief' 'flexing' 'insects' 'coconut' 'conditioning' 'expertly'
#  'proudest' 'astonished' 'bravely' 'loose' 'efficient' 'board' 'bynum'
#  'daredevils' 'makeshift' 'unconventional' 'togetherness' 'jolie' 'thirst'
#  'conga' 'charred' 'economics' 'pigeon' 'chugs' 'fantasy' 'sunken'
#  'institution' 'soccer' 'ghost' 'accepts' 'inlets' 'mosaic' 'focusing'
#  'homies' 'counselor' 'darker' 'posting' 'due' 'away' 'window'
#  'interestingly' 'pandora' 'descend' 'advice' 'candidly' 'regardless'
#  'clams' 'sleep' 'uhm' 'mountainous' 'crane' 'sleepy' 'measuring' 'troll'
#  'african' 'teller' 'noticing' 'etchings' 'grills' 'deere' 'baffling'
#  'magenta' 'unwrapped' 'slogan' 'salute' 'adventures' 'thats' 'gangs'
#  'scold' 'officers' '16' 'published' 'princesses' 'jelly' 'selection'
#  'shrubbery' 'magnificence' 'applied' 'prospective' 'flashy' 'workes'
#  'lottery' 'mulling' 'rustling' 'genetically' 'curry' 'depressed' 'skulls'
#  'paddles' 'tiresome' 'interest' 'populated' 'pompoms' 'removed' 'coated'
#  'kiteboarding' 'cactuses' 'tango' 'rave' 'grapes' 'tangle' 'tunes'
#  'cheesecake' 'injury' 'disaster' 'licked' 'work' 'touches' 'reunion'
#  'unaffected' 'tint' 'babysits' 'wholesome' 'visting' 'mikey' 'signifying'
#  'tonight' 'mosh' 'anticipation' 'jacks' 'smiling' 'attentions' 'purposes'
#  'eyeballed' 'awarding' 'seat' 'bored' 'geologists' 'robot' 'nieces'
#  'bobsled' 'leg' 'initiated' 'clay' 'carried' 'shoe' 'painting'
#  'approaching' 'dissatisfied' 'sofa' 'obey' 'dart' 'impress' 'floods'
#  'shack' 'gargoyle' 'complete' 'unpleasant' 'rubber' 'taz' 'promoted'
#  'passions' 'prize' 'poverty' 'aim' 'electrical' 'vocals' 'showcasing'
#  'fearlessly' 'red' 'contest' 'succulent' 'skiing' 'didnt' 'producer'
#  'beat' 'discipline' 'pirates' 'gradually' 'luscious' 'ass' 'grassy'
#  'elation' 'waldo' 'counts' 'downhill' 'bushes' 'greenery' 'permitted'
#  'hillside' 'kilts' 'opera' 'touched' 'batteries' 'polynesian' 'site'
#  'success' 'tune' 'parasail' 'jasey' 'smooth' 'sisterhood' 'clothes'
#  'rolled' 'adam' 'gobbled' 'wealthiest' 'grimace' '3rd' 'dwellings'
#  'terror' 'newcomers' 'landmarks' 'swing' 'crenshaw' 'rog' 'bill' 'apply'
#  'reflects' 'lol' 'judges' 'dramatically' 'delicatessen' 'considering'
#  'awaited' 'alien' 'angles' 'toasting' 'oval' 'obligations' 'vine'
#  'finger' 'professionals' 'burner' 'ita' 'witch' 'attracts' 'handsome'
#  'refuge' 'continuous' 'plates' 'falcon' 'raucous' 'addicted' 'tunnel'
#  'pictures' 'devouring' 'knott' 'cuz' 'ear' 'present' 'achieved' 'peppers'
#  'conquered' 'tire' 'violet' 'firewood' 'latter' 'clover' 'paraphernalia'
#  'wilderness' 'icecream' 'heart' 'properly' 'props' 'strait' 'political'
#  'elegance' 'stand' 'fam' 'flyer' 'lubricated' 'shades' 'randomly' 'scuba'
#  'sipped' 'behave' 'forest' 'palpable' 'panels' 'straight' 'contains'
#  'sandwich' 'eats' 'kissed' 'standby' 'awkward' 'snowballs' 'solaris'
#  'religion' 'reconnected' 'horrifying' 'wooden' 'caters' 'sabina' 'bluer'
#  'helmet' 'roars' 'minor' 'pep' 'undertone' 'snark' 'surf' 'greenlight'
#  'resisted' 'something' 'struck' 'grego' 'pledge' 'connected' 'hog'
#  'battled' 'baby' '2nd' 'pacing' 'believed' 'biathalon' 'competitors'
#  'happier' 'operate' '94' 'fluffy' 'absolutely' 'bon' 'beacon' 'telling'
#  'fearless' 'model' 'heed' 'unloaded' 'visitors' 'prettiest' 'put'
#  'vacationing' 'penthouse' 'paperwork' 'kayak' 'transformer' 'healthiest'
#  'brand' 'assure' 'cannonballs' 'bistro' 'constellations' 'thoroughfares'
#  'pavers' 'twang' 'cartoons' 'photoshoot' 'alcohol' 'telephone' 'anymore'
#  'phone' 'joked' 'associated' 'affairs' 'twilight' 'rods' 'tusks'
#  'mistaken' 'phrases' 'thefts' 'creative' 'progression' '2014' 'backed'
#  'specimens' 'pegs' 'float' 'mighty' 'extremely' 'suffer' 'models'
#  'imagine' 'drills' 'november' 'puppy' 'hunters' 'crave' 'conflict'
#  'tactic' 'prediction' 'adopting' 'fiasco' 'notified' 'thugs'
#  'performances' 'ban' 'shoulders' 'spraying' 'background' 'hungarian'
#  'pokemon' 'guardian' 'mussels' 'hatchlings' 'buries' 'reads' 'profusely'
#  'file' 'tempts' 'nemo' 'apparel' 'incredible' 'fooling' 'hates' 'stowing'
#  'offshore' 'seniors' 'counterparts' 'revered' 'rate' 'easiest' 'violin'
#  'warp' 'roof' 'rests' 'surely' 'dropping' 'commenced' 'accident' 'jerrod'
#  'lavender' 'ufos' 'east' 'injure' 'blooded' 'families' 'party' 'lamb'
#  'basilica' 'yellows' 'concentration' 'describes' 'soundtrack' 'craftsman'
#  'orphanage' 'pitted' 'babysit' 'disappear' 'garments' 'business' 'rounds'
#  'crista' 'auction' 'laptop' 'loving' 'symbolized' 'notch' 'button'
#  'france' 'mum' 'tito' 'chicks' 'tanning' 'convention' 'hardships'
#  'gingerly' 'concoction' 'ahhh' '3' 'simpsons' 'distress' 'rolls'
#  'dummies' 'spies' 'admiration' 'voters' 'streaked' 'walkers' 'cartoon'
#  'cooled' 'significant' 'national' 'wont' 'cuteness' 'standstill'
#  'blowing' 'pillars' 'shanty' 'please' 'vessels' 'thrifty' 'clearing'
#  'acquaintance' 'needy' 'files' 'guns' 'values' 'shallow' 'tool'
#  'astroturf' 'serve' 'cousins' 'perfumes' 'lame' 'pretending' 'blurred'
#  'words' 'stood' 'marnie' 'alphabetically' 'smaller' 'meaning'
#  'artistically' 'outcropping' 'recorder' 'resist' 'page' 'napkin' 'done'
#  'bathtub' 'pj' 'dragonfly' 'folklife' 'proceeds' 'rhythm' 'azure' 'surge'
#  'blast' 'patron' 'blush' 'blend' 'heavenly' 'gaining' 'refreshed'
#  'beautifully' 'whipping' 'sank' 'acre' 'closet' 'abandoned' 'horribly'
#  'clubhouse' 'cued' 'acceptable' 'residential' 'mussel' 'char'
#  'starvation' 'investigate' 'nancy' 'capstone' 'diversion' 'eiffel'
#  'veteran' 'pairing' 'anthem' 'sponsors' 'gloats' 'meditation' 'explorers'
#  'chefs' 'unanimous' 'static' 'trustees' 'karting' 'bonsai' 'mixture'
#  'concluded' 'sorority' 'forthcoming' 'chapter' 'lotf' 'crash' 'mmorpg'
#  'powerful' 'lurking' 'fantasies' 'preparation' 'actually' 'says'
#  'downtown' 'remained' 'donated' 'tonite' 'hear' 'begins' 'encourages'
#  'effortlessly' 'helicopters' 'appealing' 'manage' 'cityline' 'founding'
#  'disgust' 'hurts' 'support' 'ducklings' 'need' 'caboose' 'brats'
#  'selfishness' 'oooh' 'filming' 'crosses' 'importance' 'dehydrated'
#  'sausage' 'derby' 'bubbles' 'breaking' 'central' 'crest' 'stroller'
#  'immediately' 'ends' 'communication' 'fest' 'cindi' 'francisco' 'times'
#  'launch' 'groceries' 'selected' 'rorschach' 'carnaval' 'gazed'
#  'presentation' 'leak' 'craftsmen' 'glancing' 'sheepish' 'canine' 'kickin'
#  'mullet' 'crept' 'restrooms' 'arounds' 'fellowship' 'stoplight' 'hosts'
#  'undrinkable' 'dived' 'evening' 'immaculate' 'iggy' 'minute' 'nudist'
#  'nestled' 'beaten' 'attacks' 'bloody' 'scurrying' 'stockings' 'franciso'
#  'protrusions' 'brilliant' 'faint' 'post' 'transported' 'ranking' 'doe'
#  'gelatin' 'resides' 'channel' 'arrives' 'magazines' 'visit' 'piles'
#  'scolded' 'shells' 'gorgeous' 'avoided' 'judge' 'monorail' 'cannibalism'
#  'printed' 'loosen' 'version' 'listening' 'relative' 'sons' 'tapestry'
#  'messages' 'rather' 'intake' 'pose' 'steaks' 'hoped' 'satisfied'
#  'sightseeing' 'misfit' 'difficult' 'pass' 'dismount' 'limited' 'suckers'
#  'protesting' 'opens' 'bench' 'miss' 'breadsticks' 'shuffling' 'cruise'
#  'senso' 'game' '1800' 'ground' 'waded' 'touchdown' '42' 'second'
#  'bassist' 'respectable' 'sunsets' 'collapse' 'hitting' 'jared' 'cancer'
#  'wintertime' 'reinforcing' 'pins' 'knitting' 'rile' 'tibidabo' '84th'
#  'joyous' 'excelling' 'almost' 'screaming' 'halfway' 'fruits' 'decide'
#  'opening' 'beginnings' 'bib' 'believes' 'surfing' 'rougher' 'wistfully'
#  'zimmerman' 'cruiseliner' 'economy' 'tasty' 'iguana' 'informational'
#  'theater' 'checklist' 'lawn' 'diaper' 'lungs' 'endure' 'headliner'
#  'glanced' 'lamborghini' 'beater' 'try' 'fruity' 'gong' 'tightknit' 'mama'
#  'advise' 'valets' 'impale' 'plaque' 'surround' 'laboratory' 'tv' 'two'
#  'rod' 'faith' 'strangle' 'pulling' 'twice' 'flights' 'worn' 'cell'
#  'instant' 'scarf' 'crabbing' 'swooping' 'transpire' 'mother' 'removable'
#  'competed' 'jam' 'smells' 'sufficient' 'suspicions' 'animated' 'ridding'
#  'solidarity' 'commencement' 'laughs' 'main' 'rapid' 'recruiting'
#  'potluck' 'amaze' 'booth' 'screams' 'knit' 'raised' 'psyched' 'heat'
#  'figured' 'boulevard' 'gnarly' 'giveaways' 'gifted' 'seltzer' 'haul'
#  'escapades' 'vague' 'soak' 'glittery' 'jittery' 'marathons' 'marine'
#  'sneakers' 'webs' 'otherwise' 'albums' 'chore' 'untouched' 'hotels'
#  'grandmother' 'dinning' 'conversing' 'devoured' 'speed' 'bust' '63'
#  'eyed' 'culture' 'prefer' 'holland' 'characteristics' 'modernize'
#  'stirred' 'glazed' 'architectural' 'assistant' 'rejection' 'expo'
#  'honoring' 'claus' 'probably' 'windy' 'attended' 'plopped' 'packet'
#  'realtor' 'belly' 'persecution' 'judgemental' 'swam' 'commending' 'stuff'
#  'livens' 'olympic' 'birdwatching' 'hype' 'apartment' 'oranges'
#  'showering' '4th' 'grandma' 'polisi' 'accumulating' 'tend' 'grinned'
#  'intensified' 'hatchet' 'decreasing' 'noodle' 'mustache' 'hazing'
#  'bucket' 'agency' 'thingies' 'options' 'sunset' 'destroyed' 'dollop'
#  'unhealthy' 'tension' 'thrilled' 'travel' 'scrapbook' 'indoors'
#  'mammogram' 'surrounds' 'facebook' 'fouled' 'loc' 'limber' 'statue'
#  'spirals' 'darken' 'pitches' 'cloudy' 'nets' 'flier' 'conservation'
#  'financial' 'starbursts' 'bumming' 'customary' 'dice' 'sounded'
#  'keyboardist' 'drink' 'dracula' 'pylons' 'rotated' 'humid' 'reminds'
#  'tamales' 'liftoff' 'cuddling' 'quick' 'sacks' 'rotunda' 'busy' 'chooses'
#  'pendergrass' 'xmas' 'hutt' 'bubby' 'tasted' 'mangy' 'quint' 'drone'
#  'like' 'besides' 'trophy' 'vote' 'superman' 'cabins' 'liter' 'hordes'
#  'blurs' 'obscene' 'groups' 'beating' 'turd' 'sunshine' 'forgot'
#  'gatherings' 'feel' 'familiarizing' 'affect' 'trackers' 'cascaded'
#  'strawberries' 'resonated' 'bears' 'civilian' 'signals' 'avoid' 'lesbian'
#  'skydiver' 'porch' 'seats' 'pooch' 'encased' 'vivid' 'satisfy' 'plugged'
#  'fights' 'sandbox' 'planes' 'team' 'torrie' 'alternate' 'entire' 'legend'
#  'scarier' '981' 'convertibles' 'distressing' 'maps' 'bold' 'human'
#  'encourage' 'olden' 'attacked' 'rink' 'signifier' 'authenticity'
#  'inbetween' 'splurged' 'sundresses' 'emmy' 'peddle' 'brewing' 'communist'
#  'astronauts' 'vineyards' 'stubbornly' 'stones' '45th' 'rec' 'bradleys'
#  'deserts' 'sparklers' 'talents' 'slots' 'symbolize' 'considers' 'dashed'
#  'limo' 'expansiveness' 'occasion' 'leaping' 'immediate' 'marys' 'cleaner'
#  'unnaturally' 'sticking' 'navigated' 'either' 'wandering' 'corridors'
# ...
#  'artistry' 'seaside' 'cause' 'japanese' 'rentals' 'crime' 'dose'
#  'triomphe' 'insisted' 'handcrafted' 'rooms' 'usual' 'downward' 'attempts'
#  'beg' 'nest' 'downstream' 'fought' 'denomination' 'reasonable'
#  'lifeguards' 'watchers' 'replenish' 'leftovers' 'mounds' 'obama'
#  'facility' 'products' 'contemplated' 'surfboard' 'decade' 'technique'
#  'rely' 'congregation' 'frog' 'sponsoring' 'sidewalk' 'mustard'
#  'conveniences' 'ops' 'independence' 'relationships' 'infections'
#  'reelected' 'pampering' 'trucks' '1970s' 'suggested' 'perseverance'
#  'trickle' 'recited' 'stamina' 'errands' 'cute' 'impression' 'thunder'
#  '90' 'oils' 'fountains' 'pitched' 'scarves' 'medicine' 'trailer' 'viking'
#  'bathing' 'contemporary' 'messing' 'livelihood' 'established' 'audience'
#  'tail' 'owed' 'sweetly' 'edges' 'kindergarten' 'yin' 'patient'
#  'furnished' 'fitting' 'reacquainting' 'fades' 'grande' 'buildings'
#  'stares' 'bodega' 'lemonade' '56' 'rabbi' 'carrots' 'belligerent'
#  'roosting' 'landfill' 'moms' 'slithers' 'fairs' 'cows' 'quite' 'gethers'
#  'carolers' 'rookie' 'lines' 'slive' '500' 'clubs' 'legged' 'orchids'
#  'glam' 'doorway' 'university' 'leisure' 'craft' 'flex' 'beachgoers'
#  'incentives' 'campaign' 'sauce' 'scrap' 'shirtless' 'reputation'
#  'justify' 'foreground' 'downed' 'passersby' 'wed' 'interrupted'
#  'cigarettes' 'pretzel' 'exhilarating' 'leather' 'gentleman' 'miniature'
#  'towns' 'events' 'pooping' 'annoy' 'looming' 'junior' 'rushed'
#  'evidently' 'jaw' 'th' 'northern' 'bouquet' 'co' 'destined' 'become'
#  'jewelry' 'mannequins' 'snorkel' 'preview' 'lightened' 'developing'
#  'tourist' 'gains' 'twitter' 'dew' 'seek' 'exclaimed' 'ferris'
#  'remembrance' 'empty' 'winning' 'kiss' 'drive' 'passes' '2000' 'examine'
#  'hookah' 'save' 'stain' 'glamorous' 'maze' 'horns' 'stared' 'butchery'
#  'worthwhile' 'claim' 'journeys' 'decrease' 'padlocked' 'designed' 'arena'
#  'humbling' 'destination' 'frosty' 'shiny' 'rowdy' 'claw' 'stocking'
#  'panel' 'mowing' 'excellence' 'starring' 'olds' 'knoll' 'vacationers'
#  'awkwardness' 'amd' 'stoned' 'maid' 'hated' 'sheep' 'literally' 'notices'
#  'scheduled' 'promise' 'dedicating' 'aa' 'foul' 'laser' 'gulls' 'saints'
#  'juice' 'fog' 'show' 'acclimated' 'crowed' 'smelling' 'clipper'
#  'nourishing' 'spunky' 'hand' 'requesting' 'exclusive' 'participant'
#  'crop' 'entertainer' 'emotion' 'jennifer' 'napping' 'averted' 'pages'
#  'sudden' 'greats' 'navel' 'threat' 'lapped' 'perfect' 'pair' 'caring'
#  'ordered' 'snow' 'cola' 'begging' 'bluff' 'endured' 'frisbee' 'oddity'
#  'silliest' 'clowning' 'radiant' 'dancing' 'fund' 'mishaps' 'comrades'
#  'quarter' 'meditated' 'mundane' 'enhance' 'san' 'dinners' 'bruise'
#  'concept' 'eventually' 'pandas' 'swarmed' 'trained' 'arms' 'highland'
#  'skates' 'gauges' 'ups' 'blossomed' 'infested' 'countries' 'beanbag'
#  'wouldnt' 'canadian' 'belong' 'barefoot' 'promising' 'davidson' 'track'
#  'widow' 'reward' 'mules' 'popcorn' 'gracefully' 'plying' 'freakish'
#  'delicately' 'storybook' 'penguin' 'banks' 'syrup' 'nicest' 'fisherman'
#  'expanses' 'deeps' 'voting' 'foes' 'paths' 'strategies' 'yang'
#  'casserole' '35' 'giving' 'rested' 'auntie' 'outfielder' 'innocently'
#  'jealous' 'disgusting' 'sworn' 'guardians' 'folks' 'office' 'ducky'
#  'keepsakes' 'plant' 'chance' 'bucking' 'blossoms' 'photo' 'filling'
#  'moving' 'holders' 'former' 'backpack' 'invigorated' 'sleepovers'
#  'hissing' 'rehashing' 'werewolf' 'july' 'puked' 'rose' 'listens'
#  'situated' 'horsemen' 'homosexuals' 'musicians' 'hockey' 'starry' 'sax'
#  'popsicle' 'side' 'frame' 'combined' 'quartet' 'balconies' 'officials'
#  'adjoining' 'moonlight' 'interviews' 'headway' 'saves' 'chauffeurs'
#  'shared' 'coworker' 'careers' 'importantly' 'favors' 'cheeky' 'sings'
#  'tugging' 'rules' 'psychedelic' 'eclectic' 'fortune' 'labs' 'hammer'
#  'knelt' 'bar' 'trading' 'abouts' 'stan' 'bets' 'stupid' 'new' 'helluva'
#  'armor' 'pooches' 'shops' 'dots' 'broken' 'fragrance' 'entourage' 'marky'
#  'crossed' 'reflected' 'yearbook' 'chorus' 'futures' 'colada' 'risers'
#  'championships' 'fiddle' 'celebrated' 'quarterback' 'buried' 'shirts'
#  'undergo' 'close' 'unwraps' 'unexpectedly' 'foodies' 'defined' 'scary'
#  'patties' 'expanding' 'bottle' 'fun' 'payers' 'leaving' 'draws' 'horizon'
#  'bottles' 'oh' 'sexy' 'monday' 'errant' 'stalls' 'phones' 'explanation'
#  'character' 'bystanders' 'enjoyment' 'navigate' 'goers' 'gondola'
#  'homage' 'abyss' 'committed' 'snowing' 'white' 'canals' 'canyons' 'gooey'
#  'rollercoasters' 'risen' 'homeward' 'cheek' 'tailgating' 'unamused'
#  'merri' 'wedding' 'mystic' 'bogging' 'wang' 'breaths' 'cobble' 'funniest'
#  'popular' 'begone' 'troopers' 'crashing' 'quibble' 'hte' 'disagreeing'
#  'producing' 'may' 'courageous' 'postgame' 'farming' 'cuddly' 'lime'
#  'continent' 'trampoline' 'cal' 'geodesic' 'gasp' 'cherries' 'cord'
#  'docking' 'dang' 'event' 'facts' 'motor' 'vehicles' 'unloved' 'rossi'
#  'stomachs' 'wiener' 'wade' 'kept' 'rv' 'marched' 'tombstone' 'requested'
#  'treating' 'lowrider' 'watched' 'penguins' 'potentially' 'scampers'
#  'streaking' 'wickedly' 'perfection' 'goodness' 'collaboration' 'invited'
#  'whooping' 'taping' 'object' 'agent' 'boardwalks' 'fast' 'exited'
#  'fundraising' 'prey' 'retrieved' 'involve' 'coloration' 'lasting'
#  'exquisite' 'souvenir' 'autumn' 'married' 'dumpling' 'fact' 'exaggerated'
#  'hysterically' 'granola' 'young' 'twirled' 'boyfriends' 'fished'
#  'blackboard' 'billa' 'money' 'sweater' 'lounge' 'textures' 'volumes'
#  'reflect' 'uniquely' 'rail' 'buff' 'rollers' 'hoses' 'crested' 'shadowy'
#  'poster' 'chirping' 'learnt' 'joker' 'procession' 'purse' 'appeared'
#  'dusty' 'lof' 'dousing' 'ridden' 'train' 'helicopter' 'extraterrestrials'
#  'pinning' 'ornaments' 'nonalcoholic' 'dreamt' 'scene' 'kelis' 'speakers'
#  'walkup' 'amused' 'oath' 'hairstyles' 'refuse' 'transformed' 'farris'
#  'bask' 'quirks' 'pillow' 'watering' 'mourned' 'fetched' 'needing'
#  'blocked' 'roaring' 'historical' 'rear' 'biology' 'pigeons' 'swore'
#  'singin' 'railing' 'learning' 'waterway' 'sample' 'pinky' 'sniff' 'ramps'
#  'overlooking' 'putt' 'whack' 'mud' 'best' 'unveiled' 'flourish'
#  'butchers' 'fluids' 'crabs' 'walks' 'amusements' 'samurai' 'stampede'
#  'prettier' 'growing' 'sparky' 'presents' 'tubes' 'catch' 'library'
#  'flown' 'manual' 'gianni' 'campus' 'adored' 'approaches' 'prepped'
#  'detail' 'sal' 'repair' 'oldsmobile' 'explosives' 'examines' 'radical'
#  'butte' 'imitation' 'spiked' 'heading' 'hygiene' 'code' 'bemoaned'
#  'announcers' 'warmed' 'appetizing' 'german' 'software' 'tavo'
#  'thankfully' 'booms' 'conversation' 'entertained' 'mascot' 'wisconsin'
#  'every' 'bursting' 'migrated' 'umami' 'failed' 'idiot' 'winds' 'pushups'
#  'exception' 'entries' 'stability' 'bliss' 'peeking' 'incoming'
#  'turbulent' 'craggy' 'spread' 'connect' 'pensive' 'rake' 'practiced'
#  'brutally' 'zero' 'bong' 'texts' 'flea' 'lulu' 'thirteen' 'seri'
#  'situations' 'hikers' 'fantasyland' 'awoke' 'bats' 'productive'
#  'beckoned' 'vomited' 'serenaded' 'stressed' 'drinks' 'fizzles' 'sunny'
#  'owning' 'tips' 'tempting' 'source' 'graduates' 'healthier' 'professor'
#  'inquisitive' 'williams' 'poles' 'shoes' 'staring' 'seeds' 'uniforms'
#  'loo' 'softness' 'butt' 'memorized' 'bite' 'cubicle' 'fit' 'marked'
#  'prom' 'china' 'catcher' 'outs' 'moody' 'refreshments' 'sizzler'
#  'treacherous' 'healed' 'polluted' 'clue' 'wait' 'beautiful' 'streams'
#  'fort' 'cheering' 'recap' 'backup' 'saloon' 'boardwalk' 'shadows'
#  'aggressive' 'middle' 'carrying' 'studded' 'babys' 'yacht' 'woh' 'brian'
#  'legos' 'realy' 'difficulty' 'master' 'sandman' 'figurines' 'onlooker'
#  'seeing' 'policemen' 'awfully' 'grabbed' 'celebratory' 'sum' 'chica'
#  'flamingos' 'blocks' 'boomerangs' 'coincidental' 'identical' 'tequila'
#  'monitors' 'snapshot' 'breast' 'skin' 'drunks' 'screen' 'mobbing' 'timid'
#  'blessings' 'cameras' 'lurched' 'snacks' 'duty' 'sometimes' 'doll'
#  'crying' 'peeing' 'odder' 'drivers' 'hydrogen' 'velociraptors' 'deciding'
#  'snapping' 'sore' 'funky' 'roam' 'cheap' 'clydesdale' 'leaned'
#  'bathrooms' 'categories' 'videos' 'import' 'dangerous' 'beer'
#  'explanations' 'accountant' 'turbines' 'wildly' 'coolest' 'moist'
#  'hosted' '103rd' 'quaker' 'flora' 'anyone' 'depicting' 'strode' 'ought'
#  'brightens' 'pursuits' 'kiosk' 'escape' 'storming' 'snorkelling'
#  'saltwater' '21st' 'tge' 'crow' 'collecting' 'kingdom' 'allotted'
#  'hateful' 'renting' 'tomato' 'watcher' 'lemon' 'runs' 'oof' 'intertwined'
#  'coordinate' 'rider' 'zebra' 'nixon' 'association' 'manufactured'
#  'multitude' 'generate' 'seaport' 'heals' 'skeleton' 'drizzling' 'taken'
#  'cross' 'centerpiece' 'conjoined' 'poopers' 'sparkle' 'idea' 'framed'
#  'hiked' 'gram' 'ritz' 'merchandise' 'vans' 'plack' 'mountaintops' 'copy'
#  'friend' '10000' 'unreal' 'stunt' 'poops' 'lying' 'bucks' 'income'
#  'surfboards' 'lists' 'sized' 'buttermilk' 'tarp' 'harlem' 'others'
#  'shuttle' 'sherlock' 'kicked' 'squealed' 'nation' 'pressed' 'boogied'
#  'coming' 'themes' 'untraditional' 'creme' 'hopes' 'lads' 'tan'
#  'socialize' 'pen' 'terrain' 'fond' 'magazine' 'showers' 'flap' 'acted'
#  'roadie' 'antiques' 'make' 'shrines' 'converse' 'haircuts' 'engage'
#  'activates' 'barnyard' 'gossiping' 'inches' 'emit' 'bowl' 'precautions'
#  'portion' 'trample' 'wanted' 'horsey' 'lawson' 'back' 'sap' 'ennui'
#  'singer' 'mainland' 'ahhhh' 'mammals' 'hike' 'military' 'bags' 'carvings'
#  'handler' 'opinions' 'disguise' 'somewhere' 'overpass' 'straightforward'
#  'whimsical' 'windshield' 'motivating' '15th' 'maneuver' 'wildlife'
#  'heimlich' 'needs' 'goer' 'jaunt' 'cloud' 'boating' 'brick' 'putting'
#  'spawned' 'wreathes' 'toms' 'heres' 'necks' 'rapidly' 'peculiar'
#  'clearly' 'turns' 'cooking' 'kitty' 'noose' 'torah' 'spiraled' 'funnel'
#  'highly' 'dent' 'enemies' 'writings' 'exact' 'burning' 'brownie'
#  'remnant' 'bf' 'lizard' 'fashion' 'situation' 'maybe' 'endurance' 'pride'
#  'quilts' 'injuries' 'carving' 'exodus' 'garden' 'dusky' 'months' 'devoid'
#  'freezing' 'bassinet' 'fingers' 'sam' 'gothic' 'ornately' 'thrilling'
#  'disney' 'foamy' 'wildflowers' 'improving' 'goodbye' 'jumps' 'approached'
#  'taga' 'horizontal' 'complex' 'tended' 'handily' 'noon' 'puffballs'
#  'bros' 'frying' 'distant' 'preoccupy' 'owls' 'harsh' 'thick' 'bookshelf'
#  'tackled' 'rid' 'awnings' 'modeling' 'clash' 'riverbank' 'windmills'
#  'stacking' 'motion' 'conducting' 'effect' 'bluest' 'fairy' 'unwrap'
#  'triangle' 'deck' 'overcame' 'operating' 'geezer' 'soiling' 'accounts'
#  'gestures' 'speedboat' 'blades' 'pencil' 'fight' 'welcomes' 'strangely'
#  'vendor' 'practicing' 'services' 'confident' 'summed' 'rollercoaster'
#  'routes' 'reservation' 'whim' 'shark' 'dignitaries' 'removal' 'cells'
#  'grown' 'inside' 'icing' 'reenactments' 'boots' 'attractive' 'vets'
#  'cannon' 'bachelor' 'youtube' 'sitter' 'talker' 'fanciful' 'head'
#  'susanne' 'susan' 'varied' 'takes' 'allow' 'numer' 'temporary' 'signal'
#  'whose' 'nurturing' 'accurately' 'seaweed' 'redeemer' 'invites' 'bobbled'
#  'drunken' 'rar' 'deli' 'trashed' 'streaming' 'cotton' 'healer' 'trams'
#  'series' 'grounds' 'racer' 'guard' 'patty' 'pal' 'occupants' 'ample'
#  'forces' 'knowledge' 'image' 'turnout' 'busily' 'cellphone' 'robbery'
#  'flame' 'symbols' 'propulsion' 'scraped' 'bearing' 'jugglers' 'autograph'
#  'evacuated' 'capture' 'quieter' 'addressing' 'refuel' 'laura' 'areal'
#  'hotdog' 'folding' 'peaked' 'ferry' 'farther' 'spiky' 'statutes'
#  'daydream' 'concerns' 'meets' 'conversations' 'curly' 'mr' 'lets'
#  'forklift' 'toward' 'opportunities' 'individuals' 'museum' 'strides'
#  'hairy' 'rough' 'palm' 'erected' 'pad' 'grazers' 'subjective' 'geyser'
#  'calming' 'lunchtime' 'room' 'attending' 'deserve' 'hate' 'theatre'
#  'highway' 'matching' 'bess' 'angle' 'monkey' 'syncopated' 'fossil'
#  'embers' 'underpants' 'beaver' 'flair' 'brewery' 'struggled' 'traveled'
#  'inebriated' 'diagnosed' 'inflated' 'curiously' 'jasons' 'rendition'
#  'bowled' 'shop' 'napkins' 'introduce' 'ruled' 'contort' 'quoted'
#  'dramatic' 'girls' 'eagerly' 'fan' 'strolls' 'lesson' 'revenge'
#  'famished' 'puckered' 'top' 'browned' 'asshole' 'racing' 'blobby'
#  'estate' 'handled' 'chains' 'swallow' 'sink' 'teenager' 'ace' 'whip'
#  'dolphin' 'arrogant' 'bulb' 'request' 'ipad' 'year' 'bribe' 'encircling'
#  'nevermind' 'skit' 'hillbilly' 'thirty' 'redsox' 'talks' 'marvels'
#  'alpaca' 'cocoa' 'sprained' 'planetarium' 'blisteringly' 'preferred'
#  'ice' 'mention' 'gets' 'nook' 'jerky' 'molding' 'jubilee' 'shingles'
#  'sets' 'slides' 'marshals' 'upcoming' 'serious' 'hibachi' 'philly'
#  'certificates' 'hard' 'sheer' 'docks' 'loads' 'carpet' 'start' 'candor'
#  'silver' 'lands' 'answer' 'pizza' 'sand' 'graduated' 'saving' 'isolate'
#  'marinate' 'waiters' 'progressed' 'focused' 'dishes' 'swimsuit' 'mitch'
#  'headphones' 'groomed' 'reminded' 'chinatown' 'teach' 'salty' 'stance'
#  'rodents' 'liked' 'coaxed' 'longed' 'todays' 'religious' 'port' 'greets'
#  'showing' 'goodies' 'sailing' 'sandcastle' 'renaissance' 'acoustics'
#  'marjie' 'shovel' 'imported' 'parrots' 'hit' 'alecia' 'occasionally'
#  'collections' 'lilley' 'secure' 'snuggles' 'regains' 'fisheye' 'cupcakes'
#  'bonnets' 'photoshopped' 'escort' 'dryer' 'homework' 'eater' 'outfits'
#  'sincere' 'presenting' 'next' 'sandy' 'handprints' 'beech' 'admirably'
#  'marsupial' 'plummet' 'buddy' 'experienced' 'quest' 'fred' 'sticks'
#  'peace' 'churrascaria' 'moves' 'line' 'haha' 'link' 'jeffs' 'recites'
#  'achieving' '80' 'dads' 'mates' 'cavities' 'toddlers' 'aw' 'llama'
#  'entombed' 'website' 'glowing' 'inspecting' 'milling' 'voice' 'loft'
#  'named' 'pinball' 'hiker' 'intimidated' 'skate' 'fave' 'munchies'
#  'guided' 'geocache' 'shit' 'rob' '45' 'modern' 'cared' 'describe'
#  'prefers' 'shapes' 'cleansed' 'skimming' 'trying' 'labeled' 'dazzle'
#  'dries' 'spiderman' 'connors' 'grade' 'decades' 'showoff' 'authorities'
#  'depict' 'embarrassed' 'abiding' 'rolex' 'horrified' 'potty' 'returning'
#  'fortunate' 'albatross' 'russ' 'jutting' 'hang' 'kimmy' 'kickboxing'
#  'solve' 'passage' 'accent' 'past' 'premier' 'burial' 'muscled' 'whoever'
#  'labor' 'tainted' 'fault' 'discussing' 'relied' 'simple' 'verses'
#  'imaginary' 'variety' 'whatever' 'grownup' 'clamming' 'expand' 'spender'
#  'brood' 'settlement' 'treasures' 'grasses' 'tossing' 'cascading'
#  'refrain' 'introduces' 'cardboard' 'roller' 'organizing' 'skydiving'
#  'message' 'proved' 'thundered' 'opposing' 'shortage' 'wacked' 'graceland'
#  'honey' 'shorelines' 'arrangements' 'tell' 'neighbors' 'fanciest'
#  'wisely' 'produced' 'pubs' 'smashed' 'cascade' 'mercury' 'davey' 'rocked'
#  'dead' 'cougar' 'monster' 'disneyland' 'lessened' 'prove' 'cheery'
#  'searched' 'convenient' 'near' 'speaker' 'square' 'banners' 'progress'
#  'think' 'motel' 'commemorate' 'culminating' 'largest' 'blasts' 'buffalo'
#  'overtook' 'uncut' 'burn' 'onesies' 'smith' 'kayaked' 'underpass'
#  'tagging' 'sinking' 'leprechaun' 'inspires' 'lasted' 'gods' 'gorilla'
#  'tiara' 'customs' 'herpes' 'bff' 'volley' 'ceilings' 'occurs' 'greet'
#  'thought' 'sneaking' 'markings' 'wrist' 'halloween' 'asks' 'atmosphere'
#  'litter' 'included' 'embrace' 'picks' 'threw' 'shirt' 'pick' 'fresh'
#  'attained' 'collect' 'agains' 'intoxicating' 'brown' 'smiles' 'lower'
#  'mohammed' 'oven' 'wish' 'existence' 'backups' 'skits' 'craftsmanship'
#  'afternoon' 'unlike' 'representative' 'oversees' 'declared' 'tricorn'
#  'dozen' 'searches' 'relief' 'snaps' 'generators' 'alaskan' 'ln'
#  'passerby' 'legendary' 'wigs' 'spun' 'accepted' 'introduction' 'marshal'
#  'encore' 'box' 'catered' 'invite' 'juliet' 'visually' 'force' 'diverse'
#  'shuffle' 'grandfathers' 'local' 'smartest' 'relics' 'goodie' 'troops'
#  'different' 'stepdaughter' 'bouncing' 'depths' 'guide' 'caravel' 'woah'
#  'manfred' 'tricks' 'nt' 'sideline' 'conservative' 'piling' 'gaelic'
#  'knob' 'mime' 'surveyed' 'nido' 'sock' 'beads' 'lazy' 'logos'
#  'townspeople' 'goth' 'pigs' 'bases' 'mug' 'designer' 'babies'
#  'exploration' 'rescued' 'subway' 'amateur' 'muddied' 'experimented'
#  'bothered' 'snowboards' 'barn' 'ticket' 'reappear' 'traditionally'
#  'dolls' 'electronics' 'marrying' 'vengence' 'dy' 'longer' 'brook' 'hair'
#  'public' 'centerpieces' 'contributors' 'tomatoes' 'painter'
#  'painstakingly']

# %%
bert_voc_indices_to_use_tensor = torch.LongTensor(bert_voc_indices_to_use)
bert_word_embs_to_use = wordembs(bert_voc_indices_to_use_tensor.to('cuda')).to('cpu').detach().numpy()

# %%
# Run t-SNE on the BERT vocabulary embeddings we selected:
mytsne_words = TSNE(n_components=2,early_exaggeration=12,verbose=2,metric='cosine',init='pca',n_iter=2000)
bert_word_embs_to_use_tsne = mytsne_words.fit_transform(bert_word_embs_to_use)
# Out:
# /projects/tir5/users/cnariset/miniconda3/envs/11777/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:691: FutureWarning: 'square_distances' has been introduced in 0.24 to help phase out legacy squaring behavior. The 'legacy' setting will be removed in 1.1 (renaming of 0.26), and the default setting will be changed to True. In 1.3, 'square_distances' will be removed altogether, and distances will be squared by default. Set 'square_distances'=True to silence this warning.
#   warnings.warn(
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 12650 samples in 0.022s...
# [t-SNE] Computed neighbors for 12650 samples in 4.001s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 12650
# [t-SNE] Computed conditional probabilities for sample 2000 / 12650
# [t-SNE] Computed conditional probabilities for sample 3000 / 12650
# [t-SNE] Computed conditional probabilities for sample 4000 / 12650
# [t-SNE] Computed conditional probabilities for sample 5000 / 12650
# [t-SNE] Computed conditional probabilities for sample 6000 / 12650
# [t-SNE] Computed conditional probabilities for sample 7000 / 12650
# [t-SNE] Computed conditional probabilities for sample 8000 / 12650
# [t-SNE] Computed conditional probabilities for sample 9000 / 12650
# [t-SNE] Computed conditional probabilities for sample 10000 / 12650
# [t-SNE] Computed conditional probabilities for sample 11000 / 12650
# [t-SNE] Computed conditional probabilities for sample 12000 / 12650
# [t-SNE] Computed conditional probabilities for sample 12650 / 12650
# [t-SNE] Mean sigma: 0.156844
# [t-SNE] Computed conditional probabilities in 1.025s
# [t-SNE] Iteration 50: error = 99.8642197, gradient norm = 0.0006148 (50 iterations in 4.742s)
# [t-SNE] Iteration 100: error = 99.8217010, gradient norm = 0.0002409 (50 iterations in 3.960s)
# [t-SNE] Iteration 150: error = 99.8182678, gradient norm = 0.0001601 (50 iterations in 4.223s)
# [t-SNE] Iteration 200: error = 99.8183594, gradient norm = 0.0000862 (50 iterations in 4.559s)
# [t-SNE] Iteration 250: error = 99.8169556, gradient norm = 0.0000442 (50 iterations in 4.531s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 99.816956
# [t-SNE] Iteration 300: error = 4.0838480, gradient norm = 0.0013237 (50 iterations in 3.662s)
# [t-SNE] Iteration 350: error = 3.5740540, gradient norm = 0.0006041 (50 iterations in 3.265s)
# [t-SNE] Iteration 400: error = 3.3129182, gradient norm = 0.0003807 (50 iterations in 3.224s)
# [t-SNE] Iteration 450: error = 3.1438055, gradient norm = 0.0002749 (50 iterations in 3.247s)
# [t-SNE] Iteration 500: error = 3.0214303, gradient norm = 0.0002104 (50 iterations in 3.241s)
# [t-SNE] Iteration 550: error = 2.9279473, gradient norm = 0.0001696 (50 iterations in 3.253s)
# [t-SNE] Iteration 600: error = 2.8538966, gradient norm = 0.0001440 (50 iterations in 3.268s)
# [t-SNE] Iteration 650: error = 2.7952459, gradient norm = 0.0001245 (50 iterations in 3.269s)
# [t-SNE] Iteration 700: error = 2.7482779, gradient norm = 0.0001084 (50 iterations in 3.271s)
# [t-SNE] Iteration 750: error = 2.7095628, gradient norm = 0.0000971 (50 iterations in 3.278s)
# [t-SNE] Iteration 800: error = 2.6775267, gradient norm = 0.0000888 (50 iterations in 3.282s)
# [t-SNE] Iteration 850: error = 2.6506684, gradient norm = 0.0000818 (50 iterations in 3.278s)
# [t-SNE] Iteration 900: error = 2.6280994, gradient norm = 0.0000752 (50 iterations in 3.280s)
# [t-SNE] Iteration 950: error = 2.6083114, gradient norm = 0.0000697 (50 iterations in 3.281s)
# [t-SNE] Iteration 1000: error = 2.5910592, gradient norm = 0.0000653 (50 iterations in 3.282s)
# [t-SNE] Iteration 1050: error = 2.5762572, gradient norm = 0.0000627 (50 iterations in 3.284s)
# [t-SNE] Iteration 1100: error = 2.5636337, gradient norm = 0.0000578 (50 iterations in 3.277s)
# [t-SNE] Iteration 1150: error = 2.5522330, gradient norm = 0.0000542 (50 iterations in 3.282s)
# [t-SNE] Iteration 1200: error = 2.5419040, gradient norm = 0.0000522 (50 iterations in 3.283s)
# [t-SNE] Iteration 1250: error = 2.5325065, gradient norm = 0.0000487 (50 iterations in 3.282s)
# [t-SNE] Iteration 1300: error = 2.5239868, gradient norm = 0.0000462 (50 iterations in 3.280s)
# [t-SNE] Iteration 1350: error = 2.5162902, gradient norm = 0.0000455 (50 iterations in 3.286s)
# [t-SNE] Iteration 1400: error = 2.5093801, gradient norm = 0.0000429 (50 iterations in 3.287s)
# [t-SNE] Iteration 1450: error = 2.5029669, gradient norm = 0.0000414 (50 iterations in 3.350s)
# [t-SNE] Iteration 1500: error = 2.4970641, gradient norm = 0.0000398 (50 iterations in 3.290s)
# [t-SNE] Iteration 1550: error = 2.4915953, gradient norm = 0.0000397 (50 iterations in 3.290s)
# [t-SNE] Iteration 1600: error = 2.4865496, gradient norm = 0.0000383 (50 iterations in 3.291s)
# [t-SNE] Iteration 1650: error = 2.4820549, gradient norm = 0.0000371 (50 iterations in 3.290s)
# [t-SNE] Iteration 1700: error = 2.4778566, gradient norm = 0.0000364 (50 iterations in 3.289s)
# [t-SNE] Iteration 1750: error = 2.4739852, gradient norm = 0.0000354 (50 iterations in 3.291s)
# [t-SNE] Iteration 1800: error = 2.4704740, gradient norm = 0.0000346 (50 iterations in 3.297s)
# [t-SNE] Iteration 1850: error = 2.4671898, gradient norm = 0.0000342 (50 iterations in 3.294s)
# [t-SNE] Iteration 1900: error = 2.4641693, gradient norm = 0.0000339 (50 iterations in 3.297s)
# [t-SNE] Iteration 1950: error = 2.4613068, gradient norm = 0.0000332 (50 iterations in 3.295s)
# [t-SNE] Iteration 2000: error = 2.4586861, gradient norm = 0.0000328 (50 iterations in 3.298s)
# [t-SNE] KL divergence after 2000 iterations: 2.458686

# %%
bert_words_to_plot = bertwords[bert_voc_indices_to_plot]
print(len(bert_words_to_plot))
# Out:
# 4000

# %%
# Plot the transformed BERT vocabulary embeddings:
do_text_adjust = True

fig = plt.figure()
alltexts = list()
for i, txt in enumerate(bert_words_to_plot):
    plt.scatter(bert_word_embs_to_use_tsne[i,0], bert_word_embs_to_use_tsne[i,1], s=0)
    currtext = plt.text(bert_word_embs_to_use_tsne[i,0], bert_word_embs_to_use_tsne[i,1], txt, family='sans-serif')
    alltexts.append(currtext)
    

# Save the plot before adjusting.
plt.xlim([-151,151]); plt.ylim([-151,151])
plt.tight_layout()
plt.savefig('bert-voc-sents-tsne-viz4k-noadj.pdf', format='pdf')
if do_text_adjust:
    print('now running adjust_text')
    # Using autoalign often works better in my experience, but it can be very slow for this case, so it's false by default below:
    #numiters = adjust_text(alltexts, autoalign=True, lim=50)
    numiters = adjust_text(alltexts, autoalign=False, lim=10)
    print('done adjust text, num iterations: ', numiters)
    plt.savefig('bert-voc-sents-tsne-viz4k-adj10.pdf', format='pdf')
plt.close()
# plt.show
# Out:
# now running adjust_text
# done adjust text, num iterations:  10

# %% [markdown]
# ## DistilBERT's sentence embeddings

# %%
with open('stories_texts.txt','r') as f: all_story_texts = [line[:-1] for line in f.readlines()]
with open('captions_texts.txt','r') as f: all_caption_texts = [line[:-1] for line in f.readlines()]

# %%
from collections import Counter
import nltk, re

STOP_WORDS = set(nltk.corpus.stopwords.words())
def clean_sentence(val):
    regex = re.compile('([^\s\w]|_)+')
    sentence = regex.sub('', val).lower()
    return sentence
def clean_words(words):
    orig_words = words.copy()
    for word in orig_words:
        if word in STOP_WORDS:
            words.pop(word)
    return words
word_frequencies = clean_words(Counter(clean_sentence(' '.join(all_story_texts)).split()))

# %%
word_frequencies.most_common(100)
# Out:
# [('day', 2449),
#  ('male', 2420),
#  ('time', 2243),
#  ('went', 2032),
#  ('got', 1830),
#  ('great', 1785),
#  ('beach', 1689),
#  ('female', 1574),
#  ('location', 1563),
#  ('see', 1453),
#  ('family', 1449),
#  ('people', 1448),
#  ('fun', 1425),
#  ('friends', 1408),
#  ('beautiful', 1397),
#  ('took', 1397),
#  ('night', 1366),
#  ('nt', 1347),
#  ('everyone', 1334),
#  ('get', 1299),
#  ('birthday', 1246),
#  ('party', 1188),
#  ('go', 1142),
#  ('many', 1109),
#  ('even', 1088),
#  ('like', 1074),
#  ('picture', 1066),
#  ('water', 1042),
#  ('decided', 1019),
#  ('could', 980),
#  ('little', 975),
#  ('around', 923),
#  ('cake', 911),
#  ('made', 904),
#  ('good', 902),
#  ('together', 896),
#  ('first', 889),
#  ('us', 867),
#  ('fireworks', 858),
#  ('really', 856),
#  ('today', 843),
#  ('lot', 815),
#  ('saw', 814),
#  ('trip', 794),
#  ('ride', 768),
#  ('city', 728),
#  ('kids', 724),
#  ('show', 704),
#  ('ready', 701),
#  ('view', 696),
#  ('back', 692),
#  ('happy', 690),
#  ('came', 688),
#  ('going', 682),
#  ('race', 669),
#  ('looked', 667),
#  ('look', 664),
#  ('food', 658),
#  ('park', 636),
#  ('started', 634),
#  ('way', 629),
#  ('old', 623),
#  ('new', 622),
#  ('home', 615),
#  ('last', 607),
#  ('finally', 600),
#  ('amazing', 596),
#  ('nice', 588),
#  ('organization', 580),
#  ('friend', 576),
#  ('big', 569),
#  ('place', 557),
#  ('pictures', 549),
#  ('would', 546),
#  ('excited', 546),
#  ('enjoyed', 544),
#  ('getting', 530),
#  ('favorite', 527),
#  ('much', 524),
#  ('well', 514),
#  ('found', 511),
#  ('always', 502),
#  ('vacation', 501),
#  ('best', 498),
#  ('town', 485),
#  ('loved', 485),
#  ('wanted', 482),
#  ('long', 469),
#  ('group', 469),
#  ('love', 464),
#  ('next', 459),
#  ('sun', 452),
#  ('two', 449),
#  ('looking', 438),
#  ('game', 431),
#  ('dinner', 430),
#  ('make', 422),
#  ('sky', 420),
#  ('set', 416),
#  ('year', 415)]

# %%
word_frequencies['well']
# Out:
# 514

# %%
from sentence_transformers import SentenceTransformer
model_sent = SentenceTransformer('multi-qa-distilbert-cos-v1') # all-MiniLM-L6-v2
model_sent.to('cuda')
# Out:
# INFO:sentence_transformers.SentenceTransformer:Load pretrained SentenceTransformer: multi-qa-distilbert-cos-v1
# INFO:sentence_transformers.SentenceTransformer:Use pytorch device: cuda
# SentenceTransformer(
#   (0): Transformer({'max_seq_length': 512, 'do_lower_case': False}) with Transformer model: DistilBertModel
#   (1): Pooling({'word_embedding_dimension': 768, 'pooling_mode_cls_token': False, 'pooling_mode_mean_tokens': True, 'pooling_mode_max_tokens': False, 'pooling_mode_mean_sqrt_len_tokens': False})
#   (2): Normalize()
# )

# %%
# sentence_embeddings = model_sent.encode(all_story_texts)
sentence_embeddings = model_sent.encode(all_caption_texts)
# Out:
# Batches:   0%|          | 0/3677 [00:00<?, ?it/s]

# %%
np.random.seed(123456)
rows = np.arange(len(all_caption_texts))
np.random.shuffle(rows)
N_tsne = 10000; N_plot = 1000
bert_embs_sents_use = sentence_embeddings[rows[:N_tsne]]
bert_embs_sents_plt = sentence_embeddings[rows[:N_plot]]

# %%
# Run t-SNE on the BERT vocabulary embeddings we selected:
mytsne_words = TSNE(n_components=2,perplexity=30,early_exaggeration=12,verbose=2,metric='cosine',init='pca',n_iter=2000)
bert_sent_embs_to_use_tsne = mytsne_words.fit_transform(bert_embs_sents_use)
# Out:
# /projects/tir5/users/cnariset/miniconda3/envs/11777/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:691: FutureWarning: 'square_distances' has been introduced in 0.24 to help phase out legacy squaring behavior. The 'legacy' setting will be removed in 1.1 (renaming of 0.26), and the default setting will be changed to True. In 1.3, 'square_distances' will be removed altogether, and distances will be squared by default. Set 'square_distances'=True to silence this warning.
#   warnings.warn(
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 10000 samples in 0.014s...
# [t-SNE] Computed neighbors for 10000 samples in 2.029s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 10000
# [t-SNE] Computed conditional probabilities for sample 2000 / 10000
# [t-SNE] Computed conditional probabilities for sample 3000 / 10000
# [t-SNE] Computed conditional probabilities for sample 4000 / 10000
# [t-SNE] Computed conditional probabilities for sample 5000 / 10000
# [t-SNE] Computed conditional probabilities for sample 6000 / 10000
# [t-SNE] Computed conditional probabilities for sample 7000 / 10000
# [t-SNE] Computed conditional probabilities for sample 8000 / 10000
# [t-SNE] Computed conditional probabilities for sample 9000 / 10000
# [t-SNE] Computed conditional probabilities for sample 10000 / 10000
# [t-SNE] Mean sigma: 0.201274
# [t-SNE] Computed conditional probabilities in 0.587s
# [t-SNE] Iteration 50: error = 94.1509399, gradient norm = 0.0002792 (50 iterations in 3.423s)
# [t-SNE] Iteration 100: error = 94.1629181, gradient norm = 0.0000733 (50 iterations in 4.328s)
# [t-SNE] Iteration 150: error = 94.1695786, gradient norm = 0.0000297 (50 iterations in 4.190s)
# [t-SNE] Iteration 200: error = 94.1694489, gradient norm = 0.0000149 (50 iterations in 3.492s)
# [t-SNE] Iteration 250: error = 94.1623001, gradient norm = 0.0000110 (50 iterations in 2.902s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 94.162300
# [t-SNE] Iteration 300: error = 3.5431805, gradient norm = 0.0014614 (50 iterations in 3.097s)
# [t-SNE] Iteration 350: error = 3.0456264, gradient norm = 0.0006004 (50 iterations in 2.545s)
# [t-SNE] Iteration 400: error = 2.8175089, gradient norm = 0.0003549 (50 iterations in 2.595s)
# [t-SNE] Iteration 450: error = 2.6767173, gradient norm = 0.0002465 (50 iterations in 2.594s)
# [t-SNE] Iteration 500: error = 2.5799892, gradient norm = 0.0001863 (50 iterations in 2.590s)
# [t-SNE] Iteration 550: error = 2.5099373, gradient norm = 0.0001507 (50 iterations in 2.582s)
# [t-SNE] Iteration 600: error = 2.4575636, gradient norm = 0.0001270 (50 iterations in 2.577s)
# [t-SNE] Iteration 650: error = 2.4166491, gradient norm = 0.0001099 (50 iterations in 2.583s)
# [t-SNE] Iteration 700: error = 2.3838446, gradient norm = 0.0000968 (50 iterations in 2.650s)
# [t-SNE] Iteration 750: error = 2.3567307, gradient norm = 0.0000850 (50 iterations in 2.591s)
# [t-SNE] Iteration 800: error = 2.3342152, gradient norm = 0.0000863 (50 iterations in 2.595s)
# [t-SNE] Iteration 850: error = 2.3159542, gradient norm = 0.0000707 (50 iterations in 2.594s)
# [t-SNE] Iteration 900: error = 2.3002100, gradient norm = 0.0000646 (50 iterations in 2.599s)
# [t-SNE] Iteration 950: error = 2.2863669, gradient norm = 0.0000599 (50 iterations in 2.598s)
# [t-SNE] Iteration 1000: error = 2.2742176, gradient norm = 0.0000559 (50 iterations in 2.612s)
# [t-SNE] Iteration 1050: error = 2.2633557, gradient norm = 0.0000540 (50 iterations in 2.615s)
# [t-SNE] Iteration 1100: error = 2.2540298, gradient norm = 0.0000514 (50 iterations in 2.619s)
# [t-SNE] Iteration 1150: error = 2.2457931, gradient norm = 0.0000467 (50 iterations in 2.624s)
# [t-SNE] Iteration 1200: error = 2.2384222, gradient norm = 0.0000442 (50 iterations in 2.632s)
# [t-SNE] Iteration 1250: error = 2.2318044, gradient norm = 0.0000430 (50 iterations in 2.634s)
# [t-SNE] Iteration 1300: error = 2.2257195, gradient norm = 0.0000420 (50 iterations in 2.641s)
# [t-SNE] Iteration 1350: error = 2.2201562, gradient norm = 0.0000393 (50 iterations in 2.647s)
# [t-SNE] Iteration 1400: error = 2.2151053, gradient norm = 0.0000378 (50 iterations in 2.646s)
# [t-SNE] Iteration 1450: error = 2.2104735, gradient norm = 0.0000359 (50 iterations in 2.649s)
# [t-SNE] Iteration 1500: error = 2.2062144, gradient norm = 0.0000355 (50 iterations in 2.649s)
# [t-SNE] Iteration 1550: error = 2.2021899, gradient norm = 0.0000345 (50 iterations in 2.654s)
# [t-SNE] Iteration 1600: error = 2.1988955, gradient norm = 0.0000332 (50 iterations in 2.657s)
# [t-SNE] Iteration 1650: error = 2.1956997, gradient norm = 0.0000326 (50 iterations in 2.665s)
# [t-SNE] Iteration 1700: error = 2.1928473, gradient norm = 0.0000315 (50 iterations in 2.668s)
# [t-SNE] Iteration 1750: error = 2.1902590, gradient norm = 0.0000309 (50 iterations in 2.667s)
# [t-SNE] Iteration 1800: error = 2.1876678, gradient norm = 0.0000291 (50 iterations in 2.675s)
# [t-SNE] Iteration 1850: error = 2.1851969, gradient norm = 0.0000282 (50 iterations in 2.674s)
# [t-SNE] Iteration 1900: error = 2.1826894, gradient norm = 0.0000283 (50 iterations in 2.680s)
# [t-SNE] Iteration 1950: error = 2.1807055, gradient norm = 0.0000273 (50 iterations in 2.677s)
# [t-SNE] Iteration 2000: error = 2.1787097, gradient norm = 0.0000272 (50 iterations in 2.681s)
# [t-SNE] KL divergence after 2000 iterations: 2.178710

# %%
# Plot the keyword+context strings.
fig = plt.figure()
alltexts = list()
N_plot = 1000
for i, txt in enumerate(np.array(all_caption_texts)[rows[:N_plot]]):
    plt.scatter(bert_sent_embs_to_use_tsne[i,0], bert_sent_embs_to_use_tsne[i,1], s=1, c='red', marker='*')
    currtext = plt.text(bert_sent_embs_to_use_tsne[i,0], bert_sent_embs_to_use_tsne[i,1], txt, family='sans-serif')
    alltexts.append(currtext)    
plt.tight_layout()
plt.savefig('bert-sen-captions-tsne-viz1k-noadj.pdf', format='pdf')

# print('now running adjust_text')
# numiters = adjust_text(alltexts, autoalign=False, lim=10)
# print('done adjust text, num iterations: ', numiters)
# plt.savefig('viz-bert-ctx-viz700-adj10.pdf', format='pdf')

plt.close()

# %% [markdown]
# ## BERT's contextualized word embeddings

# %%
# This function loads lines from a file, tokenizes them, and processes lines containing keyword, 
# up to a limit of maxLines lines. 
# It returns both the tokenized lines and the integer positions in those tokenized lines of the keyword.
def loadAndTokenizeLinesAndFindKeyword(filename, keyword, maxLines):
    print("Loading lines from file", filename)
    f = open(filename,'r')
    lines = []
    keywordIndices = []
    numSkipped = 0
    for line in f:
        # Tokenize input
        lineForBERT = "[CLS] " + line.rstrip() + " [SEP]"
        tokenized_text = tokenizer.tokenize(lineForBERT)
        if keyword in tokenized_text:
            keywordIndex = tokenized_text.index(keyword)
            lines.append(tokenized_text)
            keywordIndices.append(keywordIndex)
            if len(lines) >= maxLines:
                break
        else:
            # print("Keyword \"", keyword, "\" not found in line: ", tokenized_text)
            numSkipped += 1
    print("Done. ", len(lines)," lines loaded, ", numSkipped, " lines skipped.")
    return lines, keywordIndices

# %%
keywordLines, keywordIndices = loadAndTokenizeLinesAndFindKeyword("captions_texts.txt", "well", 15000)
# keywordLines, keywordIndices = loadAndTokenizeLinesAndFindKeyword("stories_texts.txt", "well", 15000)
# keywordLines, keywordIndices = loadAndTokenizeLinesAndFindKeyword("values.books-wiki.15k.txt", "values", 15000)
# Out:
# Loading lines from file captions_texts.txt
# Done.  416  lines loaded,  117229  lines skipped.

# %%
# Now we will use BERT to encode the sentences we loaded and save the embeddings from the final layer 
# at the position of the keyword.
embs = np.empty((0,model.config.hidden_size), float)
# Go through all tokenized lines and keyword indices:
for tok, ind in tqdm(zip(keywordLines, keywordIndices)):
    #print(tok, ind)
    # Convert token to vocabulary indices
    indexed_tokens = tokenizer.convert_tokens_to_ids(tok)
    # segments_ids will hold indices associated with the first and second sentences in BERT.
    # We just use sentence A indices for all tokens:
    segments_ids = [0] * len(tok)
    # Convert inputs to PyTorch tensors
    tokens_tensor = torch.tensor([indexed_tokens])
    segments_tensors = torch.tensor([segments_ids])
    # Compute hidden states for each layer:
    with torch.no_grad():
        outputs = model(tokens_tensor.to('cuda'), token_type_ids=segments_tensors.to('cuda'))
        # The first element of the output holds the hidden states of the last layer of BERT.
        encoded_layers = outputs[0]
        # encoded_layers has shape (batch size, sequence length, model hidden dimension)
        assert tuple(encoded_layers.shape) == (1, len(indexed_tokens), model.config.hidden_size)
        # Get the hidden state for the keyword position, convert it to a numpy array, and add it to the embs matrix.
        embs = np.append(embs, [encoded_layers[0][ind][:].squeeze().to('cpu').numpy()], axis=0)
# Out:
# 416it [00:09, 44.84it/s]

# %%
embs.shape
# Out:
# (416, 1024)

# %%
# Run t-SNE on the contextualized embeddings:
mytsne_tokens = TSNE(n_components=2,perplexity=50,early_exaggeration=12,verbose=2,metric='cosine',init='pca',n_iter=2000)
embs_tsne = mytsne_tokens.fit_transform(embs)
# Out:
# /projects/tir5/users/cnariset/miniconda3/envs/11777/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:691: FutureWarning: 'square_distances' has been introduced in 0.24 to help phase out legacy squaring behavior. The 'legacy' setting will be removed in 1.1 (renaming of 0.26), and the default setting will be changed to True. In 1.3, 'square_distances' will be removed altogether, and distances will be squared by default. Set 'square_distances'=True to silence this warning.
#   warnings.warn(
# [t-SNE] Computing 151 nearest neighbors...
# [t-SNE] Indexed 416 samples in 0.001s...
# [t-SNE] Computed neighbors for 416 samples in 0.027s...
# [t-SNE] Computed conditional probabilities for sample 416 / 416
# [t-SNE] Mean sigma: 0.257149
# [t-SNE] Computed conditional probabilities in 0.100s
# [t-SNE] Iteration 50: error = 53.4609833, gradient norm = 0.4045932 (50 iterations in 0.113s)
# [t-SNE] Iteration 100: error = 57.4858017, gradient norm = 0.3791026 (50 iterations in 0.113s)
# [t-SNE] Iteration 150: error = 58.4458733, gradient norm = 0.3735373 (50 iterations in 0.117s)
# [t-SNE] Iteration 200: error = 56.1848869, gradient norm = 0.4256278 (50 iterations in 0.112s)
# [t-SNE] Iteration 250: error = 57.4413300, gradient norm = 0.3926392 (50 iterations in 0.108s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 57.441330
# [t-SNE] Iteration 300: error = -0.2040093, gradient norm = 0.0018377 (50 iterations in 0.079s)
# [t-SNE] Iteration 350: error = -0.6096529, gradient norm = 0.0006438 (50 iterations in 0.073s)
# [t-SNE] Iteration 400: error = -0.8582039, gradient norm = 0.0003938 (50 iterations in 0.074s)
# [t-SNE] Iteration 450: error = -1.0302064, gradient norm = 0.0002855 (50 iterations in 0.073s)
# [t-SNE] Iteration 500: error = -1.1629781, gradient norm = 0.0002252 (50 iterations in 0.073s)
# [t-SNE] Iteration 550: error = -1.2699192, gradient norm = 0.0001865 (50 iterations in 0.075s)
# [t-SNE] Iteration 600: error = -1.3610100, gradient norm = 0.0001606 (50 iterations in 0.073s)
# [t-SNE] Iteration 650: error = -1.4393557, gradient norm = 0.0001403 (50 iterations in 0.073s)
# [t-SNE] Iteration 700: error = -1.5061669, gradient norm = 0.0001249 (50 iterations in 0.074s)
# [t-SNE] Iteration 750: error = -1.5661962, gradient norm = 0.0001098 (50 iterations in 0.073s)
# [t-SNE] Iteration 800: error = -1.6199410, gradient norm = 0.0001015 (50 iterations in 0.073s)
# [t-SNE] Iteration 850: error = -1.6697376, gradient norm = 0.0000927 (50 iterations in 0.075s)
# [t-SNE] Iteration 900: error = -1.7179704, gradient norm = 0.0000913 (50 iterations in 0.073s)
# [t-SNE] Iteration 950: error = -1.7609391, gradient norm = 0.0000851 (50 iterations in 0.073s)
# [t-SNE] Iteration 1000: error = -1.8017378, gradient norm = 0.0000772 (50 iterations in 0.074s)
# [t-SNE] Iteration 1050: error = -1.8372213, gradient norm = 0.0000730 (50 iterations in 0.073s)
# [t-SNE] Iteration 1100: error = -1.8709288, gradient norm = 0.0000676 (50 iterations in 0.073s)
# [t-SNE] Iteration 1150: error = -1.9026352, gradient norm = 0.0000624 (50 iterations in 0.075s)
# [t-SNE] Iteration 1200: error = -1.9326799, gradient norm = 0.0000583 (50 iterations in 0.073s)
# [t-SNE] Iteration 1250: error = -1.9613147, gradient norm = 0.0000548 (50 iterations in 0.073s)
# [t-SNE] Iteration 1300: error = -1.9881296, gradient norm = 0.0000521 (50 iterations in 0.075s)
# [t-SNE] Iteration 1350: error = -2.0140173, gradient norm = 0.0000492 (50 iterations in 0.073s)
# [t-SNE] Iteration 1400: error = -2.0386007, gradient norm = 0.0000472 (50 iterations in 0.073s)
# [t-SNE] Iteration 1450: error = -2.0624764, gradient norm = 0.0000450 (50 iterations in 0.074s)
# [t-SNE] Iteration 1500: error = -2.0850868, gradient norm = 0.0000430 (50 iterations in 0.074s)
# [t-SNE] Iteration 1550: error = -2.1069646, gradient norm = 0.0000412 (50 iterations in 0.073s)
# [t-SNE] Iteration 1600: error = -2.1279857, gradient norm = 0.0000396 (50 iterations in 0.075s)
# [t-SNE] Iteration 1650: error = -2.1484017, gradient norm = 0.0000381 (50 iterations in 0.073s)
# [t-SNE] Iteration 1700: error = -2.1678998, gradient norm = 0.0000367 (50 iterations in 0.073s)
# [t-SNE] Iteration 1750: error = -2.1866424, gradient norm = 0.0000356 (50 iterations in 0.075s)
# [t-SNE] Iteration 1800: error = -2.2049103, gradient norm = 0.0000343 (50 iterations in 0.073s)
# [t-SNE] Iteration 1850: error = -2.2225127, gradient norm = 0.0000333 (50 iterations in 0.073s)
# [t-SNE] Iteration 1900: error = -2.2396693, gradient norm = 0.0000322 (50 iterations in 0.075s)
# [t-SNE] Iteration 1950: error = -2.2562399, gradient norm = 0.0000311 (50 iterations in 0.078s)
# [t-SNE] Iteration 2000: error = -2.2723422, gradient norm = 0.0000302 (50 iterations in 0.073s)
# [t-SNE] KL divergence after 2000 iterations: -2.272342

# %%
# Create the list of strings to plot; these will be the keyword with partial context to either side.
keywordWithContext = []
# The window size is the (max) number of subword units on either side of the keyword to display.
windowSize = 5
# The following flag determines whether to merge partial-word units into single words when displaying the context.
mergeSubwordUnits = True
# The following flag determines whether to remove BERT boundary tokens like [CLS] and [SEP] when displaying the context.
removeBoundaryTokens = True
for txt, ind in zip(keywordLines, keywordIndices):
    startInd = ind - windowSize
    if startInd < 0:
        startInd = 0
    currKeywordWithContext = " ".join(txt[startInd:ind+windowSize+1])
    if mergeSubwordUnits:
        currKeywordWithContext = currKeywordWithContext.replace(" ##", "")
        currKeywordWithContext = currKeywordWithContext.replace("##", "")
    if removeBoundaryTokens:
        currKeywordWithContext = currKeywordWithContext.replace("[CLS] ", "")
        currKeywordWithContext = currKeywordWithContext.replace(" [SEP]", "")
    keywordWithContext.append(currKeywordWithContext)

# %%
# Plot the keyword+context strings.
fig = plt.figure()
alltexts = list()
for i, txt in enumerate(keywordWithContextToPlot):
    plt.scatter(embs_tsne[i,0], embs_tsne[i,1], s=0)
    currtext = plt.text(embs_tsne[i,0], embs_tsne[i,1], txt, family='sans-serif')
    alltexts.append(currtext)
    
plt.tight_layout()
plt.savefig('bert-voc-captions-well-tsne-viz500-noadj.pdf', format='pdf')
# print('now running adjust_text')
# # numiters = adjust_text(alltexts, autoalign=True, lim=50)
# numiters = adjust_text(alltexts, autoalign=False, lim=10)
# print('done adjust text, num iterations: ', numiters)
# plt.savefig('bert-voc-captions-well-tsne-viz500-adj10.pdf', format='pdf')

plt.close()
